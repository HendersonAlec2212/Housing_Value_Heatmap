# %% [markdown]
# This script will load the csv file of clean information
# aggregate if needed (to get $_per_sqFT, a value neede for intensity of heatmap)
# insert each row as a document that will have the address as the key
# may need two databases for now
#
# - one that has all of the addresses so they can be compiled into a list for the heat map
# - one that has addresses as keys to the lat/lng so that they can be used to make a marker.
#
# can document.find_one(address_query) pull the document that has matching info to address?

# %%
#-------------------------------------------------------------------------------------------------------------------------#
# https://www.w3schools.com/python/python_mongodb_query.asp

def query_database():
    # pull number of elements in list, display for user, request name of DB to pull
    # return the input, db_query = string dtype
    
    dblist = client.list_database_names()

    list_len = len(dblist)
    print(f'{list_len} Databases Found ... ')
    print()
    for name in dblist:
        print(f'-{name}')
        print()
    print('------------------------')

    database_query = input("Which Database would you like to load? Use exact spelling.. ")
    if database_query not in dblist:
        raise ValueError(f'Database "{database_query}" Not Found.')
    else:
        print()
        print(f'Database "{database_query}" Successfully Loaded..')
        print()
        return database_query
    
#-------------------------------------------------------------------------------------------------------------------------#

def query_collections(database_query):
    # list all collections in DB
    # request db to display collections
    # return string of which collection user selected to view documents
    
    #### add back feature to method?
    
#     database = query_database()
    loop = True
    collection_list = client[database_query].list_collection_names()
    collection_dict = {}
    x = len(collection_list)
   
    
    print(f' {x} collection(s) found in "{database_query}"')
    print('------------------------')
    # print each collection in list i.e. DB
    for count, collection in enumerate(collection_list):
        
        collection_dict[f'{collection}'] = count
        
        print()
        print(f'{collection}')
        print()
    print('------------------------')    
    print()
    
   # keep asking the query if the user misspells the collection

    while loop == True:
        try:
            collection_query = input("Which collection would you like to load? ")

            if collection_query not in collection_list:
                raise ValueError("Collection not found, Try again.")
                
            else:
                print("Collection found, Loading Documents.")
                loop = False
                return collection_query
                

        except ValueError:
            print()
            print(f'Collection "{collection_query}" not found, Try again.')
            print()
#-------------------------------------------------------------------------------------------------------------------------#

def query_documents(database_query,collection_query):

    collection = client[database_query][collection_query]
    print("want to see all documents? enter 'all' in both inputs. ")
    
    query_key = input('Desired Field in documents to pull matching results? ')
    query_value = input('Desired Value? NOTE: this will not pull numbers unless edited ')
    
    

    # EXAMPLE ------------------
    # query = {"query_key": query_value}
    # --------------------------
    if query_value == 'all' or query_key == 'all':
        address_documents = collection.find()
    else:
        query = {query_key:query_value}

        address_documents = collection.find(query)


    doc_list = []
    for doc in address_documents:
        doc_list.append(doc)
    return doc_list

# %%
import os
import pandas as pd
import pymongo
os.getcwd()
# Out:
# 'C:\\Users\\Alec\\Documents\\Programming_Resources\\Boot_Camp\\16_project03\\LOCAL\\IPYNB files'

# %%
# set up pymongo connection

# https://docs.mongodb.com/manual/reference/default-mongodb-port/

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
database = query_database()
collection = query_collections(database)



documents = query_documents(database,collection)
display(documents)
# Out:
# 5 Databases Found ...
#
# -admin
#
# -commerce_db
#
# -config
#
# -jj_earnings
#
# -local
#
# ------------------------
# Which Database would you like to load? Use exact spelling.. jj_earnings
#
# Database "jj_earnings" Successfully Loaded..
#
#  2 collection(s) found in "jj_earnings"
# ------------------------
#
# shifts
#
#
# test
#
# ------------------------
#
# Which collection would you like to load? shifts
# Collection found, Loading Documents.
# want to see all documents? enter 'all' in both inputs.
# Desired Field in documents to pull matching results? all
# Desired Value? NOTE: this will not pull numbers unless edited all
# [{'_id': ObjectId('61d91ad96ff8d725c83e3302'),
#   'date_of_shift': '12-31-21',
#   'tips': 41.0,
#   'hours': 7.75,
#   'earnings': 114.62,
#   'effective_wage': 14.79,
#   'old_job_earnings': 127.88,
#   'old_job_comparison': 13.25,
#   'starting_mileage': 0,
#   'ending_mileage': 0,
#   'change_in_mileage': 0},
#  {'_id': ObjectId('61d91ad96ff8d725c83e3303'),
#   'date_of_shift': '01-01-22',
#   'tips': 45.0,
#   'hours': 6.0,
#   'earnings': 102.0,
#   'effective_wage': 17.0,
#   'old_job_earnings': 99.0,
#   'old_job_comparison': -3.0,
#   'starting_mileage': 0,
#   'ending_mileage': 0,
#   'change_in_mileage': 0},
#  {'_id': ObjectId('61d91ad96ff8d725c83e3304'),
#   'date_of_shift': '01-02-22',
#   'tips': 71.0,
#   'hours': 10.2,
#   'earnings': 167.9,
#   'effective_wage': 16.46,
#   'old_job_earnings': 168.3,
#   'old_job_comparison': 0.4,
#   'starting_mileage': 0,
#   'ending_mileage': 0,
#   'change_in_mileage': 0},
#  {'_id': ObjectId('61d91ad96ff8d725c83e3305'),
#   'date_of_shift': '01-05-22',
#   'tips': 71.0,
#   'hours': 7.0,
#   'earnings': 137.5,
#   'effective_wage': 19.64,
#   'old_job_earnings': 115.5,
#   'old_job_comparison': -22.0,
#   'starting_mileage': 75190,
#   'ending_mileage': 75245,
#   'change_in_mileage': 55},
#  {'_id': ObjectId('61d91ad96ff8d725c83e3306'),
#   'date_of_shift': '01-06-22',
#   'tips': 41.0,
#   'hours': 4.0,
#   'earnings': 79.0,
#   'effective_wage': 19.75,
#   'old_job_earnings': 66.0,
#   'old_job_comparison': -13.0,
#   'starting_mileage': 75255,
#   'ending_mileage': 75290,
#   'change_in_mileage': 35},
#  {'_id': ObjectId('61d91ad96ff8d725c83e3307'),
#   'date_of_shift': '01-07-22',
#   'tips': 85.0,
#   'hours': 10.5,
#   'earnings': 184.75,
#   'effective_wage': 17.6,
#   'old_job_earnings': 173.25,
#   'old_job_comparison': -11.5,
#   'starting_mileage': 75300,
#   'ending_mileage': 75369,
#   'change_in_mileage': 69},
#  {'_id': ObjectId('61dc54b33b42743863bfc2ec'),
#   'date_of_shift': '01-09-22',
#   'tips': 91.0,
#   'hours': 10.5,
#   'earnings': 190.75,
#   'effective_wage': 18.17,
#   'old_job_earnings': 173.25,
#   'old_job_comparison': -17.5,
#   'starting_mileage': 75382,
#   'ending_mileage': 75444,
#   'change_in_mileage': 62},
#  {'_id': ObjectId('61dfb0a6a503c5ad66df537c'),
#   'date_of_shift': '01-12-22',
#   'tips': 81.0,
#   'hours': 10.5,
#   'earnings': 180.75,
#   'effective_wage': 17.21,
#   'old_job_earnings': 173.25,
#   'old_job_comparison': -7.5,
#   'starting_mileage': 75448,
#   'ending_mileage': 75523,
#   'change_in_mileage': 75},
#  {'_id': ObjectId('61e1025ce59c7ac3d9ea36e1'),
#   'date_of_shift': '01-13-22',
#   'tips': 38.0,
#   'hours': 4.0,
#   'earnings': 76.0,
#   'effective_wage': 19.0,
#   'old_job_earnings': 66.0,
#   'old_job_comparison': -10.0,
#   'starting_mileage': 75533,
#   'ending_mileage': 75562,
#   'change_in_mileage': 29},
#  {'_id': ObjectId('61e23a050027cc00d1b95f15'),
#   'date_of_shift': '01-14-22',
#   'tips': 99.0,
#   'hours': 8.5,
#   'earnings': 179.75,
#   'effective_wage': 21.15,
#   'old_job_earnings': 140.25,
#   'old_job_comparison': -39.5,
#   'starting_mileage': 75575,
#   'ending_mileage': 75640,
#   'change_in_mileage': 65}]

# %%
data_path = '../clean_data/clean_home_no_dupes.csv'

clean_data = pd.read_csv(data_path)
clean_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                         owner  \
# 0           0             0              PIERSON GARY DON
# 1           1             1            PORTER STEPHEN RAY
# 2           2             2                PORTER AUDIE L
# 3           3             3               STICKEL CALEB &
# 4           4             4  VALLEY VIEW COMMUNITY CENTER
#
#                                            address_1               address_2  \
# 0      5403 S COUNTY ROAD 1140MIDLAND, TX 79706-7128  COUNTY RD 01140 5403 S
# 1             5401 S COUNTY RD 1140MIDLAND, TX 79706  COUNTY RD 01140 5401 S
# 2      5407 S COUNTY ROAD 1140MIDLAND, TX 79706-7128  COUNTY RD 01140 5407 S
# 3  CHRISTINA ELAINE STICKEL4700 E COUNTY RD 140MI...  COUNTY RD 00140 4700 E
# 4             E F JONESP O BOX 3270MIDLAND, TX 79702        FM RD 01213 5502
#
#       city  state                               full_address  \
# 0  MIDLAND  TEXAS  COUNTY RD 01140   5403   S MIDLAND, TEXAS
# 1  MIDLAND  TEXAS  COUNTY RD 01140   5401   S MIDLAND, TEXAS
# 2  MIDLAND  TEXAS  COUNTY RD 01140   5407   S MIDLAND, TEXAS
# 3  MIDLAND  TEXAS  COUNTY RD 00140   4700   E MIDLAND, TEXAS
# 4  MIDLAND  TEXAS          FM RD 01213   5502 MIDLAND, TEXAS
#
#    2021_building_value  2021_land_value  2021_total_value  land_acre  \
# 0              94160.0          12000.0          106160.0       1.00
# 1              55950.0          58920.0          114870.0       4.91
# 2             117590.0          27240.0          144830.0       1.00
# 3             289130.0          48000.0          337130.0       1.00
# 4              69280.0          27240.0           96520.0       2.27
#
#    land_sqft  est_tax  total_sqft  $_per_building_sqft  \
# 0    43560.0   844.42      1316.0                 71.6
# 1   213880.0  1613.89      1032.0                 54.2
# 2    43560.0  1010.62      1592.0                 73.9
# 3    43560.0  4159.64      2553.0                113.3
# 4    98881.0     0.00      1984.0                 34.9
#
#    $_per_total_value_sqft        lat         lng
# 0                    80.7  32.003127 -102.065677
# 1                   111.3  32.003127 -102.065677
# 2                    91.0  32.003127 -102.065677
# 3                   132.1  31.920417 -102.097027
# 4                    48.6  31.905234 -102.032287

# %%
clean_data.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'owner',
#  'address_1',
#  'address_2',
#  'city',
#  'state',
#  'full_address',
#  '2021_building_value',
#  '2021_land_value',
#  '2021_total_value',
#  'land_acre',
#  'land_sqft',
#  'est_tax',
#  'total_sqft',
#  '$_per_building_sqft',
#  '$_per_total_value_sqft',
#  'lat',
#  'lng']

# %%
clean_data = clean_data.drop(columns = ['Unnamed: 0','Unnamed: 0.1'])
clean_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-fc33096851b8> in <module>
# ----> 1 clean_data = clean_data.drop(columns = ['Unnamed: 0','Unnamed: 0.1'])
#       2 clean_data.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0' 'Unnamed: 0.1'] not found in axis"

# %%
clean_data['full_address'][0]
# Out:
# 'COUNTY RD 01140   5403   S MIDLAND, TEXAS'

# %%
test_cell = clean_data['address_2'][0]
clean_cell = test_cell.replace(' ',"_")
display(clean_cell)
# Out:
# 'COUNTY_RD_01140___5403___S'

# %%
# result = (' '*number_of_spaces_desired).join(string_to_replace_spaces.split())


split_cell = (' '*1).join(test_cell.split())

split_cell
# Out:
# 'COUNTY RD 01140 5403 S'

# %%
address_2 = clean_data['address_2']
address_list = address_2.to_list()

clean_address_2_list = []

for row in range(len(address_list)):
    x = address_2[row]
    print(x)
    clean_address_2 = (' '*1).join(x.split())
    clean_address_2_list.append(clean_address_2)
    print(clean_address_2)
    print('--------------')
# Out:
# COUNTY RD 01140 5403 S
# COUNTY RD 01140 5403 S
# --------------
# COUNTY RD 01140 5401 S
# COUNTY RD 01140 5401 S
# --------------
# COUNTY RD 01140 5407 S
# COUNTY RD 01140 5407 S
# --------------
# COUNTY RD 00140 4700 E
# COUNTY RD 00140 4700 E
# --------------
# FM RD 01213 5502
# FM RD 01213 5502
# --------------
# FM RD 01213 4015
# FM RD 01213 4015
# --------------
# ECR 130 4001
# ECR 130 4001
# --------------
# COUNTY RD 01270 9009 S
# COUNTY RD 01270 9009 S
# --------------
# COUNTY RD 00174 9201 W
# COUNTY RD 00174 9201 W
# --------------
# COUNTY RD 01270 8601 S
# COUNTY RD 01270 8601 S
# --------------
# COUNTY RD 00170 9315 W
# COUNTY RD 00170 9315 W
# --------------
# COUNTY RD 00174 9205 W
# COUNTY RD 00174 9205 W
# --------------
# COUNTY RD 00174 9404 W
# COUNTY RD 00174 9404 W
# --------------
# COUNTY RD 01135 4007 S
# COUNTY RD 01135 4007 S
# --------------
# COUNTY RD 00140 2408 E
# COUNTY RD 00140 2408 E
# --------------
# COUNTY RD 01140 4912 S
# COUNTY RD 01140 4912 S
# --------------
# FM RD 00307 13304
# FM RD 00307 13304
# --------------
# FM RD 00307 13300
# FM RD 00307 13300
# --------------
# COUNTY RD 01060 2201 S
# COUNTY RD 01060 2201 S
# --------------
# COUNTY RD 01060 2701 S
# COUNTY RD 01060 2701 S
# --------------
# COUNTY RD 00110 13200 E
# COUNTY RD 00110 13200 E
# --------------
# COUNTY RD 00110 13400 E
# COUNTY RD 00110 13400 E
# --------------
# COUNTY RD 00113 13109 E
# COUNTY RD 00113 13109 E
# --------------
# COUNTY RD 00113 13009 E
# COUNTY RD 00113 13009 E
# --------------
# COUNTY RD 00113 13007 E
# COUNTY RD 00113 13007 E
# --------------
# COUNTY RD 01058 2516 S
# COUNTY RD 01058 2516 S
# --------------
# COUNTY RD 01058 2606 S
# COUNTY RD 01058 2606 S
# --------------
# COUNTY RD 00113 13101 E
# COUNTY RD 00113 13101 E
# --------------
# COUNTY RD 00120 13401 E
# COUNTY RD 00120 13401 E
# --------------
# COUNTY RD 00120 13501 E
# COUNTY RD 00120 13501 E
# --------------
# COUNTY RD 00190 4400 E
# COUNTY RD 00190 4400 E
# --------------
# COUNTY RD 00190 5500 E
# COUNTY RD 00190 5500 E
# --------------
# SOLOMON LN 529
# SOLOMON LN 529
# --------------
# SOLOMON LN 27
# SOLOMON LN 27
# --------------
# SOLOMON LN 519
# SOLOMON LN 519
# --------------
# SOLOMON LN 503
# SOLOMON LN 503
# --------------
# SOLOMON LN 502
# SOLOMON LN 502
# --------------
# SOLOMON LN 414
# SOLOMON LN 414
# --------------
# SOLOMON LN 320
# SOLOMON LN 320
# --------------
# POLO CLUB RD 5115
# POLO CLUB RD 5115
# --------------
# POLO CLUB RD 5207
# POLO CLUB RD 5207
# --------------
# POLO CLUB RD 5305
# POLO CLUB RD 5305
# --------------
# CARDINAL LN 1716
# CARDINAL LN 1716
# --------------
# POLO CLUB RD 5300
# POLO CLUB RD 5300
# --------------
# BLUEBIRD BRANCH CT 5000
# BLUEBIRD BRANCH CT 5000
# --------------
# MIDKIFF RD 5200 N
# MIDKIFF RD 5200 N
# --------------
# BLUEBIRD LN 2500
# BLUEBIRD LN 2500
# --------------
# BLUEBIRD LN 2310
# BLUEBIRD LN 2310
# --------------
# KIMSEY WAY 1
# KIMSEY WAY 1
# --------------
# MOCKINGBIRD LN 3509
# MOCKINGBIRD LN 3509
# --------------
# MOCKINGBIRD LN 4113
# MOCKINGBIRD LN 4113
# --------------
# MOCKINGBIRD LN 4301
# MOCKINGBIRD LN 4301
# --------------
# CARDINAL LN 4222
# CARDINAL LN 4222
# --------------
# CARDINAL LN 4204
# CARDINAL LN 4204
# --------------
# CARDINAL LN 3914
# CARDINAL LN 3914
# --------------
# CARDINAL LN 3708
# CARDINAL LN 3708
# --------------
# CARDINAL LN 3704
# CARDINAL LN 3704
# --------------
# CARDINAL LN 3602
# CARDINAL LN 3602
# --------------
# CARDINAL LN 3508
# CARDINAL LN 3508
# --------------
# CARDINAL LN 3504
# CARDINAL LN 3504
# --------------
# CARDINAL LN 3303
# CARDINAL LN 3303
# --------------
# MIDKIFF RD 5201 N
# MIDKIFF RD 5201 N
# --------------
# CARDINAL LN 3307
# CARDINAL LN 3307
# --------------
# CARDINAL LN 3707
# CARDINAL LN 3707
# --------------
# CARDINAL LN 3803
# CARDINAL LN 3803
# --------------
# CARDINAL LN 3811
# CARDINAL LN 3811
# --------------
# CARDINAL LN 3905
# CARDINAL LN 3905
# --------------
# CARDINAL LN 4209
# CARDINAL LN 4209
# --------------
# CARDINAL LN 4221
# CARDINAL LN 4221
# --------------
# BLUEBIRD LN 3500
# BLUEBIRD LN 3500
# --------------
# BLUEBIRD LN 3410
# BLUEBIRD LN 3410
# --------------
# BLUEBIRD LN 3400
# BLUEBIRD LN 3400
# --------------
# BLUEBIRD LN 3310
# BLUEBIRD LN 3310
# --------------
# BLUEBIRD LN 3302
# BLUEBIRD LN 3302
# --------------
# MOCKINGBIRD LN 4400
# MOCKINGBIRD LN 4400
# --------------
# MOCKINGBIRD LN 4406
# MOCKINGBIRD LN 4406
# --------------
# MOCKINGBIRD LN 4500
# MOCKINGBIRD LN 4500
# --------------
# TATTENHAM COR 14
# TATTENHAM COR 14
# --------------
# TATTENHAM COR 4
# TATTENHAM COR 4
# --------------
# TATTENHAM COR 2
# TATTENHAM COR 2
# --------------
# TATTENHAM CT 1
# TATTENHAM CT 1
# --------------
# TATTENHAM COR 3
# TATTENHAM COR 3
# --------------
# TATTENHAM COR 5
# TATTENHAM COR 5
# --------------
# TATTENHAM COR 7
# TATTENHAM COR 7
# --------------
# TATTENHAM COR 9
# TATTENHAM COR 9
# --------------
# TATTENHAM COR 11
# TATTENHAM COR 11
# --------------
# TATTENHAM COR 15
# TATTENHAM COR 15
# --------------
# TANFORAN AV 4403
# TANFORAN AV 4403
# --------------
# TANFORAN AV 4407
# TANFORAN AV 4407
# --------------
# TANFORAN AV 4411
# TANFORAN AV 4411
# --------------
# TANFORAN AV 4413
# TANFORAN AV 4413
# --------------
# TANFORAN AV 4415
# TANFORAN AV 4415
# --------------
# TANFORAN AV 4419
# TANFORAN AV 4419
# --------------
# TANFORAN AV 4420
# TANFORAN AV 4420
# --------------
# TANFORAN AV 4410
# TANFORAN AV 4410
# --------------
# TANFORAN AV 4402
# TANFORAN AV 4402
# --------------
# TANFORAN AV 4400
# TANFORAN AV 4400
# --------------
# FIR DR 6007
# FIR DR 6007
# --------------
# WOOD DR 4519
# WOOD DR 4519
# --------------
# MEADOWVIEW LN 6009
# MEADOWVIEW LN 6009
# --------------
# GREEN HILL CT 6008
# GREEN HILL CT 6008
# --------------
# GREEN HILL CT 6015
# GREEN HILL CT 6015
# --------------
# MOCKINGBIRD LN 3700
# MOCKINGBIRD LN 3700
# --------------
# HWY 00349 6101 N
# HWY 00349 6101 N
# --------------
# HWY 00349 6201 N
# HWY 00349 6201 N
# --------------
# FM RD 01788 0 S
# FM RD 01788 0 S
# --------------
# COUNTY RD 01060 2500 S
# COUNTY RD 01060 2500 S
# --------------
# COUNTY RD 00110 0 E
# COUNTY RD 00110 0 E
# --------------
# COUNTY RD 01069 3112 S
# COUNTY RD 01069 3112 S
# --------------
# COUNTY RD 01069 3111 S
# COUNTY RD 01069 3111 S
# --------------
# COUNTY RD 01140 3808 S
# COUNTY RD 01140 3808 S
# --------------
# HWY 00158 4901 E
# HWY 00158 4901 E
# --------------
# COUNTY RD 01110 0 S
# COUNTY RD 01110 0 S
# --------------
# COUNTY RD 01110 2403 S
# COUNTY RD 01110 2403 S
# --------------
# COUNTY RD 01110 2313 S
# COUNTY RD 01110 2313 S
# --------------
# COUNTY RD 00103 8400 E
# COUNTY RD 00128 5609 E
# COUNTY RD 00128 5609 E
# --------------
# COUNTY RD 00128 5707 E
# COUNTY RD 00128 5707 E
# --------------
# HWY 00158 4418 E
# HWY 00158 4418 E
# --------------
# HWY 00158 4419 E
# HWY 00158 4419 E
# --------------
# FM RD 01213 3801
# FM RD 01213 3801
# --------------
# FM RD 01213 3801
# FM RD 01213 3801
# --------------
# HWY 00158 4200 E
# HWY 00158 4200 E
# --------------
# HWY 00158 4306 E
# HWY 00158 4306 E
# --------------
# HWY 00158 4409 E
# HWY 00158 4409 E
# --------------
# HWY 00158 4413 E
# HWY 00158 4413 E
# --------------
# HWY 00158 4414 E
# HWY 00158 4414 E
# --------------
# HWY 00158 4304 E
# HWY 00158 4304 E
# --------------
# FM RD 01213 4615
# FM RD 01213 4615
# --------------
# FM RD 01213 5113
# FM RD 01213 5113
# --------------
# FM RD 01213 5005
# FM RD 01213 5005
# --------------
# COUNTY RD 00132 4014 E
# COUNTY RD 00132 4014 E
# --------------
# FM RD 01213 4605
# FM RD 01213 4605
# --------------
# FM RD 01213 4603
# FM RD 01213 4603
# --------------
# FM RD 01213 4611
# FM RD 01213 4611
# --------------
# COUNTY RD 00144 3306 E
# COUNTY RD 00144 3306 E
# --------------
# COUNTY RD 00140 3204 E
# COUNTY RD 00140 3204 E
# --------------
# COUNTY RD 00144 3300 E
# COUNTY RD 00144 3300 E
# --------------
# COUNTY RD 01156 5608 S
# COUNTY RD 01156 5608 S
# --------------
# COUNTY RD 01156 5602 S
# COUNTY RD 01156 5602 S
# --------------
# COUNTY RD 00144 3200 E
# COUNTY RD 00144 3200 E
# --------------
# COUNTY RD 00144 3110 E
# COUNTY RD 00144 3110 E
# --------------
# COUNTY RD 01156 5609 S
# COUNTY RD 01156 5609 S
# --------------
# COUNTY RD 01156 5809 S
# COUNTY RD 01156 5809 S
# --------------
# COUNTY RD 01156 5905 S
# COUNTY RD 01156 5905 S
# --------------
# COUNTY RD 01156 5603 S
# COUNTY RD 01156 5603 S
# --------------
# COUNTY RD 00144 3209 E
# COUNTY RD 00144 3209 E
# --------------
# COUNTY RD 01156 5704 S
# COUNTY RD 01156 5704 S
# --------------
# COUNTY RD 01160 6001 S
# COUNTY RD 01160 6001 S
# --------------
# COUNTY RD 01135 3600 S
# COUNTY RD 01135 3600 S
# --------------
# COUNTY RD 01135 4000 S
# COUNTY RD 01135 4000 S
# --------------
# COUNTY RD 01135 4000 S
# COUNTY RD 01135 4000 S
# --------------
# LAMESA RD 1511 N
# LAMESA RD 1511 N
# --------------
# LAMESA RD 1507 N
# LAMESA RD 1507 N
# --------------
# LAMESA RD 1505 N
# LAMESA RD 1505 N
# --------------
# LAMESA RD 1503 N
# LAMESA RD 1503 N
# --------------
# TERRELL ST 1500 N
# TERRELL ST 1500 N
# --------------
# TERRELL ST 1504 N
# TERRELL ST 1504 N
# --------------
# TERRELL ST 1506 N
# TERRELL ST 1506 N
# --------------
# TERRELL ST 1508 N
# TERRELL ST 1508 N
# --------------
# TERRELL ST 1510 N
# DORMARD AV 111 W
# DORMARD AV 111 W
# --------------
# DORMARD AV 109 W
# DORMARD AV 109 W
# --------------
# DORMARD AV 107 W
# DORMARD AV 107 W
# --------------
# DORMARD AV 105 W
# DORMARD AV 105 W
# --------------
# DORMARD AV 103 W
# DORMARD AV 103 W
# --------------
# DORMARD AV 101 W
# DORMARD AV 101 W
# --------------
# PECOS ST 3006 N
# PECOS ST 3006 N
# --------------
# PECOS ST 3002 N
# PECOS ST 3002 N
# --------------
# PECOS ST 3000 N
# PECOS ST 3000 N
# --------------
# PECOS ST 3007 N
# PECOS ST 3007 N
# --------------
# PECOS ST 3005 N
# PECOS ST 3005 N
# --------------
# PECOS ST 3003 N
# PECOS ST 3003 N
# --------------
# PECOS ST 3001 N
# PECOS ST 3001 N
# --------------
# DORMARD AV 700 W
# DORMARD AV 700 W
# --------------
# DORMARD AV 702 W
# DORMARD AV 702 W
# --------------
# DORMARD AV 704 W
# DORMARD AV 704 W
# --------------
# DORMARD AV 706 W
# DORMARD AV 706 W
# --------------
# DORMARD AV 708 W
# DORMARD AV 708 W
# --------------
# DORMARD AV 710 W
# DORMARD AV 710 W
# --------------
# DORMARD AV 712 W
# DORMARD AV 712 W
# --------------
# DORMARD AV 714 W
# DORMARD AV 714 W
# --------------
# DORMARD AV 718 W
# DORMARD AV 718 W
# --------------
# LAFAYETTE PL 1
# LAFAYETTE PL 1
# --------------
# LAFAYETTE PL 2
# LAFAYETTE PL 2
# --------------
# LAFAYETTE PL 3
# LAFAYETTE PL 3
# --------------
# LAFAYETTE PL 4
# LAFAYETTE PL 4
# --------------
# LAFAYETTE PL 12
# LAFAYETTE PL 12
# --------------
# LAFAYETTE PL 13
# LAFAYETTE PL 13
# --------------
# LAFAYETTE PL 14
# LAFAYETTE PL 14
# --------------
# LAFAYETTE PL 15
# LAFAYETTE PL 15
# --------------
# LAFAYETTE PL 17
# LAFAYETTE PL 17
# --------------
# LAFAYETTE PL 18
# LAFAYETTE PL 18
# --------------
# LAFAYETTE PL 19
# LAFAYETTE PL 19
# --------------
# LAFAYETTE PL 22
# LAFAYETTE PL 22
# --------------
# LAFAYETTE PL 25
# LAFAYETTE PL 25
# --------------
# LAFAYETTE PL 26
# LAFAYETTE PL 26
# --------------
# LAFAYETTE PL 27
# LAFAYETTE PL 27
# --------------
# LAFAYETTE PL 28
# LAFAYETTE PL 28
# --------------
# LAFAYETTE PL 29
# LAFAYETTE PL 29
# --------------
# LAFAYETTE PL 31
# LAFAYETTE PL 31
# --------------
# LAFAYETTE PL 32
# LAFAYETTE PL 32
# --------------
# LAFAYETTE PL 33
# LAFAYETTE PL 33
# --------------
# LAFAYETTE PL 34
# LAFAYETTE PL 34
# --------------
# LAFAYETTE PL 35
# LAFAYETTE PL 35
# --------------
# LAFAYETTE PL 36
# LAFAYETTE PL 36
# --------------
# LAFAYETTE PL 38
# LAFAYETTE PL 38
# --------------
# LAFAYETTE PL 39
# LAFAYETTE PL 39
# --------------
# LAFAYETTE PL 40
# LAFAYETTE PL 40
# TERRACE AV 2609
# --------------
# TERRACE AV 2607
# TERRACE AV 2607
# --------------
# TERRACE AV 2605
# TERRACE AV 2605
# --------------
# TERRACE AV 2603
# TERRACE AV 2603
# --------------
# TERRACE AV 2601
# TERRACE AV 2601
# --------------
# TERRACE AV 2600
# TERRACE AV 2600
# --------------
# TERRACE AV 2602
# TERRACE AV 2602
# --------------
# TERRACE AV 2604
# TERRACE AV 2604
# --------------
# TERRACE AV 2606
# TERRACE AV 2606
# --------------
# TERRACE AV 2608
# TERRACE AV 2608
# --------------
# TERRACE AV 2610
# TERRACE AV 2610
# --------------
# TERRACE AV 2612
# TERRACE AV 2612
# --------------
# FANNIN AV 2613
# FANNIN AV 2613
# --------------
# FANNIN AV 2611
# FANNIN AV 2611
# --------------
# FANNIN AV 2609
# FANNIN AV 2609
# --------------
# FANNIN AV 2605
# FANNIN AV 2605
# --------------
# FANNIN AV 2603
# FANNIN AV 2603
# --------------
# FANNIN AV 2601
# FANNIN AV 2601
# --------------
# TERRACE AV 2500
# TERRACE AV 2500
# --------------
# TERRACE AV 2502
# TERRACE AV 2502
# --------------
# TERRACE AV 2504
# TERRACE AV 2504
# --------------
# TERRACE AV 2506
# TERRACE AV 2506
# --------------
# TERRACE AV 2508
# TERRACE AV 2508
# --------------
# TERRACE AV 2510
# TERRACE AV 2510
# --------------
# TERRACE AV 2512
# TERRACE AV 2512
# --------------
# FANNIN AV 2513
# FANNIN AV 2513
# --------------
# FANNIN AV 2511
# FANNIN AV 2511
# --------------
# FANNIN AV 2509
# FANNIN AV 2509
# --------------
# FANNIN AV 2507
# FANNIN AV 2507
# --------------
# FANNIN AV 2505
# FANNIN AV 2505
# --------------
# FANNIN AV 2503
# FANNIN AV 2503
# --------------
# FANNIN AV 2501
# FANNIN AV 2501
# --------------
# WADLEY AV 2501 W
# WADLEY AV 2501 W
# --------------

# %%
clean_data['Address 2'] = clean_address_2_list
clean_data['Address 2']
# Out:
# 0       COUNTY RD 01140 5403 S
# 1       COUNTY RD 01140 5401 S
# 2       COUNTY RD 01140 5407 S
# 3       COUNTY RD 00140 4700 E
# 4             FM RD 01213 5502
#                  ...
# 6429            FANNIN AV 2507
# 6430            FANNIN AV 2505
# 6431            FANNIN AV 2503
# 6432            FANNIN AV 2501
# 6433          WADLEY AV 2501 W
# Name: Address 2, Length: 6434, dtype: object

# %%
clean_data
# Out:
#                              Owner  \
# 0                 PIERSON GARY DON
# 1               PORTER STEPHEN RAY
# 2                   PORTER AUDIE L
# 3                  STICKEL CALEB &
# 4     VALLEY VIEW COMMUNITY CENTER
# ...                            ...
# 6429             MC CLAINE BRIAN K
# 6430                CROSS THOMAS C
# 6431               WEAVER ANDREW R
# 6432                   MELTON TOBY
# 6433  DAVIS NANCY CHANDLER TRUSTEE
#
#                                               Address 1  \
# 0         5403 S COUNTY ROAD 1140MIDLAND, TX 79706-7128
# 1                5401 S COUNTY RD 1140MIDLAND, TX 79706
# 2         5407 S COUNTY ROAD 1140MIDLAND, TX 79706-7128
#
# [6434 rows x 15 columns]

# %%
test_cell = clean_data['Address 1'][0]
clean_cell = test_cell.replace(' ',"_")
display(clean_cell)
# Out:
# '5403_S_COUNTY_ROAD_1140MIDLAND,_TX_79706-7128'

# %%
clean_data = clean_data.rename(columns ={
    'Owner':'owner',
    'Address 1':'address_1',
    'Address 2':'address_2',
    'City':'city',
    'State':'state',
    'Full Address':'full_address',
    '2021 Building Value':'2021_building_value',
    '2021 Land Value':'2021_land_value',
    '2021 Total Value':'2021_total_value',
    'Land (Acre)':'land_acre',
    'Land (SQFT)':'land_sqft',
    'Est Tax':'est_tax',
    'Total SQFT':'total_sqft',
    '$/Building SQFT':'$_per_building_sqft',
    '$/Total Value SQFT':'$_per_total_value_sqft'
})

# %%
clean_data
# Out:
#                              owner  \
# 0                 PIERSON GARY DON
# 1               PORTER STEPHEN RAY
# 2                   PORTER AUDIE L
# 3                  STICKEL CALEB &
# 4     VALLEY VIEW COMMUNITY CENTER
# ...                            ...
# 6429             MC CLAINE BRIAN K
# 6430                CROSS THOMAS C
# 6431               WEAVER ANDREW R
# 6432                   MELTON TOBY
# 6433  DAVIS NANCY CHANDLER TRUSTEE
#
#                                               address_1  \
# 0         5403 S COUNTY ROAD 1140MIDLAND, TX 79706-7128
# 1                5401 S COUNTY RD 1140MIDLAND, TX 79706
# 2         5407 S COUNTY ROAD 1140MIDLAND, TX 79706-7128
# 3     CHRISTINA ELAINE STICKEL4700 E COUNTY RD 140MI...
# 4                E F JONESP O BOX 3270MIDLAND, TX 79702
# ...                                                 ...
# 6429              2507 FANNIN AVEMIDLAND, TX 79705-7311
# 6430              2505 FANNIN AVEMIDLAND, TX 79705-7311
# 6431                    2503 FANNIN AVMIDLAND, TX 79705
# 6432                    2501 FANNIN AVMIDLAND, TX 79705
# 6433                    3107 STANOLINDMIDLAND, TX 79705
#
#                    address_2     city  state  \
# 0     COUNTY RD 01140 5403 S  MIDLAND  TEXAS
# 1     COUNTY RD 01140 5401 S  MIDLAND  TEXAS
# 2     COUNTY RD 01140 5407 S  MIDLAND  TEXAS
# 3     COUNTY RD 00140 4700 E  MIDLAND  TEXAS
# 4           FM RD 01213 5502  MIDLAND  TEXAS
# ...                      ...      ...    ...
# 6429          FANNIN AV 2507  MIDLAND  TEXAS
# 6430          FANNIN AV 2505  MIDLAND  TEXAS
# 6431          FANNIN AV 2503  MIDLAND  TEXAS
# 6432          FANNIN AV 2501  MIDLAND  TEXAS
# 6433        WADLEY AV 2501 W  MIDLAND  TEXAS
#
#                                    full_address  2021_building_value  \
# 0     COUNTY RD 01140   5403   S MIDLAND, TEXAS              94160.0
# 1     COUNTY RD 01140   5401   S MIDLAND, TEXAS              55950.0
# 2     COUNTY RD 01140   5407   S MIDLAND, TEXAS             117590.0
# 3     COUNTY RD 00140   4700   E MIDLAND, TEXAS             289130.0
# 4             FM RD 01213   5502 MIDLAND, TEXAS              69280.0
# ...                                         ...                  ...
# 6429            FANNIN AV   2507 MIDLAND, TEXAS             227720.0
# 6430            FANNIN AV   2505 MIDLAND, TEXAS             236320.0
# 6431            FANNIN AV   2503 MIDLAND, TEXAS             241760.0
# 6432            FANNIN AV   2501 MIDLAND, TEXAS             311570.0
# 6433        WADLEY AV   2501   W MIDLAND, TEXAS             250750.0
#
#       2021_land_value  2021_total_value  land_acre  land_sqft  est_tax  \
# 0             12000.0          106160.0      1.000    43560.0   844.42
# 1             58920.0          114870.0      4.910   213880.0  1613.89
# 2             27240.0          144830.0      1.000    43560.0  1010.62
# 3             48000.0          337130.0      1.000    43560.0  4159.64
# 4             27240.0           96520.0      2.270    98881.0     0.00
# ...               ...               ...        ...        ...      ...
# 6429          24770.0          252490.0      0.253    11008.0  3873.71
# 6430          23900.0          260220.0      0.244    10624.0  4000.13
# 6431          23130.0          264890.0      0.236    10280.0  4076.50
# 6432          26210.0          337780.0      0.267    11648.0  5268.64
# 6433          23490.0          274240.0      0.240    10440.0  4777.69
#
#       total_sqft  $_per_building_sqft  $_per_total_value_sqft
# 0         1316.0                 71.6                    80.7
# 1         1032.0                 54.2                   111.3
# 2         1592.0                 73.9                    91.0
# 3         2553.0                113.3                   132.1
# 4         1984.0                 34.9                    48.6
# ...          ...                  ...                     ...
# 6429      2139.0                106.5                   118.0
# 6430      2193.0                107.8                   118.7
# 6431      1992.0                121.4                   133.0
# 6432      3262.0                 95.5                   103.5
# 6433      3158.0                 79.4                    86.8
#
# [6434 rows x 15 columns]

# %%
data_no_dupes = clean_data.drop_duplicates()

# %%
data_no_dupes.count()
# Out:
# owner                     6433
# address_1                 6433
# address_2                 6433
# city                      6433
# state                     6433
# full_address              6433
# 2021_building_value       6433
# 2021_land_value           6433
# 2021_total_value          6433
# land_acre                 6433
# land_sqft                 6433
# est_tax                   6433
# total_sqft                6433
# $_per_building_sqft       6433
# $_per_total_value_sqft    6433
# lat                       6433
# lng                       6433
# dtype: int64

# %%
data_no_dupes.head()
# Out:
#                           owner  \
# 0              PIERSON GARY DON
# 1            PORTER STEPHEN RAY
# 2                PORTER AUDIE L
# 3               STICKEL CALEB &
# 4  VALLEY VIEW COMMUNITY CENTER
#
#                                            address_1               address_2  \
# 0      5403 S COUNTY ROAD 1140MIDLAND, TX 79706-7128  COUNTY RD 01140 5403 S
# 1             5401 S COUNTY RD 1140MIDLAND, TX 79706  COUNTY RD 01140 5401 S
# 2      5407 S COUNTY ROAD 1140MIDLAND, TX 79706-7128  COUNTY RD 01140 5407 S
# 3  CHRISTINA ELAINE STICKEL4700 E COUNTY RD 140MI...  COUNTY RD 00140 4700 E
# 4             E F JONESP O BOX 3270MIDLAND, TX 79702        FM RD 01213 5502
#
#       city  state                               full_address  \
# 0  MIDLAND  TEXAS  COUNTY RD 01140   5403   S MIDLAND, TEXAS
# 1  MIDLAND  TEXAS  COUNTY RD 01140   5401   S MIDLAND, TEXAS
# 2  MIDLAND  TEXAS  COUNTY RD 01140   5407   S MIDLAND, TEXAS
# 3  MIDLAND  TEXAS  COUNTY RD 00140   4700   E MIDLAND, TEXAS
# 4  MIDLAND  TEXAS          FM RD 01213   5502 MIDLAND, TEXAS
#
#    2021_building_value  2021_land_value  2021_total_value  land_acre  \
# 0              94160.0          12000.0          106160.0       1.00
# 1              55950.0          58920.0          114870.0       4.91
# 2             117590.0          27240.0          144830.0       1.00
# 3             289130.0          48000.0          337130.0       1.00
# 4              69280.0          27240.0           96520.0       2.27
#
#    land_sqft  est_tax  total_sqft  $_per_building_sqft  \
# 0    43560.0   844.42      1316.0                 71.6
# 1   213880.0  1613.89      1032.0                 54.2
# 2    43560.0  1010.62      1592.0                 73.9
# 3    43560.0  4159.64      2553.0                113.3
# 4    98881.0     0.00      1984.0                 34.9
#
#    $_per_total_value_sqft        lat         lng
# 0                    80.7  32.003127 -102.065677
# 1                   111.3  32.003127 -102.065677
# 2                    91.0  32.003127 -102.065677
# 3                   132.1  31.920417 -102.097027
# 4                    48.6  31.905234 -102.032287

# %%
index = data_no_dupes.index.to_list()
index_length = len(index)
index_length
# Out:
# 6433

# %%
row = data_no_dupes.iloc[[0]]
row_dict = row.to_dict()
row_dict
# Out:
# {'owner': {0: 'PIERSON GARY DON'},
#  'address_1': {0: '5403 S COUNTY ROAD 1140MIDLAND, TX 79706-7128'},
#  'address_2': {0: 'COUNTY RD 01140 5403 S'},
#  'city': {0: 'MIDLAND'},
#  'state': {0: 'TEXAS'},
#  'full_address': {0: 'COUNTY RD 01140   5403   S MIDLAND, TEXAS'},
#  '2021_building_value': {0: 94160.0},
#  '2021_land_value': {0: 12000.0},
#  '2021_total_value': {0: 106160.0},
#  'land_acre': {0: 1.0},
#  'land_sqft': {0: 43560.0},
#  'est_tax': {0: 844.42},
#  'total_sqft': {0: 1316.0},
#  '$_per_building_sqft': {0: 71.6},
#  '$_per_total_value_sqft': {0: 80.7},
#  'lat': {0: 32.0031271},
#  'lng': {0: -102.0656771}}

# %%
# declare Database
db = client.midland_property_info

# declare collection(s)

# collection for the results of the main search page, PROPERTY ID search
properties = db.properties
test_properties = db.test_properties

# %%
for i in index:

    # row = row of index value, i
    row = data_no_dupes.iloc[[i]]
    # turns row of df into dictionary to allow to inserting to MongoDB
    row_dict = row.to_dict()
    clean_doc = {}
    clean_entry = {}
    # edit the row to equal only {key:value} NOT {key:{key_2: value}}
    clean_doc['owner']= row_dict['owner'][i]
    clean_doc['address_1']= row_dict['address_1'][i]
    clean_doc['address_2']= row_dict['address_2'][i]
    clean_doc['city']= row_dict['city'][i]
    clean_doc['state']= row_dict['state'][i]
    clean_doc['full_address']= row_dict['full_address'][i]
    clean_doc['2021_building_value']= row_dict['2021_building_value'][i]
    clean_doc['2021_land_value']= row_dict['2021_land_value'][i]
    clean_doc['2021_total_value']= row_dict['2021_total_value'][i]
    clean_doc['land_acre']= row_dict['land_acre'][i]
    clean_doc['land_sqft']= row_dict['land_sqft'][i]
    clean_doc['est_tax']= row_dict['est_tax'][i]
    clean_doc['total_sqft']= row_dict['total_sqft'][i]
    clean_doc['$_per_building_sqft']= row_dict['$_per_building_sqft'][i]
    clean_doc['$_per_total_value_sqft']= row_dict['$_per_total_value_sqft'][i]
    clean_doc['lat']= row_dict['lat'][i]
    clean_doc['lng']= row_dict['lng'][i]
    
    properties.insert_one(clean_doc)
#     test_properties.insert_one(clean_doc)
    
    print()
    print(f'Row {i} saved in MongoDB "midland_property_info"')
    print('-----------------------------------')
# Out:
# Row 0 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row
saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6000 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6008 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6016 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6024 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6032 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6040 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6048 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6056 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6064 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6072 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6080 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6088 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6096 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6104 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6112 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6120 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6128 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6136 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6144 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6152 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6160 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6168 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6176 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6184 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6192 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6200 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6208 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6216 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6224 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6232 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6240 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6248 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6256 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6264 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6272 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6280 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6288 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6296 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6304 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6312 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6320 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6328 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6336 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6344 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6352 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6360 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6368 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6376 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6384 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6392 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6400 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6408 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6416 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6424 saved in MongoDB "midland_property_info"
# -----------------------------------
#
# Row 6432 saved in MongoDB "midland_property_info"
# -----------------------------------

# %%
database = query_database()
collection = query_collections(database)
documents = query_documents(database,collection)


documents = query_documents('midland_property_info','properties')
display(documents)
# Out:
# want to see all documents? enter 'all' in both inputs.
# Desired Field in documents to pull matching results? all
# Desired Value? NOTE: this will not pull numbers unless edited all
# [{'_id': ObjectId('61e60f8d68822cfcae1f4fb2'),
#   'owner': 'PIERSON GARY DON',
#   'address_1': '5403 S COUNTY ROAD 1140MIDLAND, TX 79706-7128',
#   'address_2': 'COUNTY RD 01140 5403 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01140   5403   S MIDLAND, TEXAS',
#   '2021_building_value': 94160.0,
#   '2021_land_value': 12000.0,
#   '2021_total_value': 106160.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 844.42,
#   'total_sqft': 1316.0,
#   '$_per_building_sqft': 71.6,
#   '$_per_total_value_sqft': 80.7,
#   'lat': 32.0031271,
#   'lng': -102.0656771},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fb3'),
#   'owner': 'PORTER STEPHEN RAY',
#   'address_1': '5401 S COUNTY RD 1140MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 01140 5401 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01140   5401   S MIDLAND, TEXAS',
#   '2021_building_value': 55950.0,
#   '2021_land_value': 58920.0,
#   '2021_total_value': 114870.0,
#   'land_acre': 4.91,
#   'land_sqft': 213880.0,
#   'est_tax': 1613.89,
#   'total_sqft': 1032.0,
#   '$_per_building_sqft': 54.2,
#   '$_per_total_value_sqft': 111.3,
#   'lat': 32.0031271,
#   'lng': -102.0656771},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fb4'),
#   'owner': 'PORTER AUDIE L',
#   'address_1': '5407 S COUNTY ROAD 1140MIDLAND, TX 79706-7128',
#   'address_2': 'COUNTY RD 01140 5407 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01140   5407   S MIDLAND, TEXAS',
#   '2021_building_value': 117590.0,
#   '2021_land_value': 27240.0,
#   '2021_total_value': 144830.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 1010.62,
#   'total_sqft': 1592.0,
#   '$_per_building_sqft': 73.9,
#   '$_per_total_value_sqft': 91.0,
#   'lat': 32.0031271,
#   'lng': -102.0656771},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fb5'),
#   'owner': 'STICKEL CALEB &',
#   'address_1': 'CHRISTINA ELAINE STICKEL4700 E COUNTY RD 140MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00140 4700 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00140   4700   E MIDLAND, TEXAS',
#   '2021_building_value': 289130.0,
#   '2021_land_value': 48000.0,
#   '2021_total_value': 337130.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 4159.64,
#   'total_sqft': 2553.0,
#   '$_per_building_sqft': 113.3,
#   '$_per_total_value_sqft': 132.1,
#   'lat': 31.9204168,
#   'lng': -102.0970267},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fb6'),
#   'owner': 'VALLEY VIEW COMMUNITY CENTER',
#   'address_1': 'E F JONESP O BOX 3270MIDLAND, TX 79702',
#   'address_2': 'FM RD 01213 5502',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'FM RD 01213   5502 MIDLAND, TEXAS',
#   '2021_building_value': 69280.0,
#   '2021_land_value': 27240.0,
#   '2021_total_value': 96520.0,
#   'land_acre': 2.27,
#   'land_sqft': 98881.0,
#   'est_tax': 0.0,
#   'total_sqft': 1984.0,
#   '$_per_building_sqft': 34.9,
#   '$_per_total_value_sqft': 48.6,
#   'lat': 31.9052337,
#   'lng': -102.0322873},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fb7'),
#   'owner': 'PUENTES MARIA CONCEPCION',
#   'address_1': '4015 FM RD 1213MIDLAND, TX 79701-1684',
#   'address_2': 'FM RD 01213 4015',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'FM RD 01213   4015 MIDLAND, TEXAS',
#   '2021_building_value': 48520.0,
#   '2021_land_value': 24000.0,
#   '2021_total_value': 72520.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 483.15,
#   'total_sqft': 416.0,
#   '$_per_building_sqft': 116.6,
#   '$_per_total_value_sqft': 174.3,
#   'lat': 31.9052337,
#   'lng': -102.0322873},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fb8'),
#   'owner': 'ROBISON JUSTIN THAD',
#   'address_1': 'P O BOX 4132MIDLAND, TX 79704',
#   'address_2': 'ECR 130 4001',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'ECR 130   4001 MIDLAND, TEXAS',
#   '2021_building_value': 333480.0,
#   '2021_land_value': 104340.0,
#   '2021_total_value': 380200.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 4680.45,
#   'total_sqft': 2296.0,
#   '$_per_building_sqft': 145.2,
#   '$_per_total_value_sqft': 165.6,
#   'lat': 31.9973456,
#   'lng': -102.0779146},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fb9'),
#   'owner': 'BURNS J S',
#   'address_1': '9009 S COUNTY ROAD 1270MIDLAND, TX 79706 6037',
#   'address_2': 'COUNTY RD 01270 9009 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01270   9009   S MIDLAND, TEXAS',
#   '2021_building_value': 89040.0,
#   '2021_land_value': 112350.0,
#   '2021_total_value': 201390.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 1751.74,
#   'total_sqft': 1080.0,
#   '$_per_building_sqft': 82.4,
#   '$_per_total_value_sqft': 186.5,
#   'lat': 32.0034529,
#   'lng': -102.0640217},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fba'),
#   'owner': 'JOHNSON CHARLENE FORSYTH',
#   'address_1': '9201 W COUNTY RD 174MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00174 9201 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00174   9201   W MIDLAND, TEXAS',
#   '2021_building_value': 106800.0,
#   '2021_land_value': 54880.0,
#   '2021_total_value': 161680.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 367.96,
#   'total_sqft': 1352.0,
#   '$_per_building_sqft': 79.0,
#   '$_per_total_value_sqft': 119.6,
#   'lat': 31.9829912,
#   'lng': -102.2319422},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fbb'),
#   'owner': 'FRASIER CHARLOTTE DIANE',
#   'address_1': '8601 S COUNTY RD 1270MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 01270 8601 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01270   8601   S MIDLAND, TEXAS',
#   '2021_building_value': 59460.0,
#   '2021_land_value': 7200.0,
#   '2021_total_value': 66660.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 151.95,
#   'total_sqft': 1732.0,
#   '$_per_building_sqft': 34.3,
#   '$_per_total_value_sqft': 38.5,
#   'lat': 32.0034529,
#   'lng': -102.0640217},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fbc'),
#   'owner': 'STEVE AND DANA MIZZLES REVOCABLE TRUST',
#   'address_1': '9315 W COUNTY ROAD 170MIDLAND, TX 79706-6001',
#   'address_2': 'COUNTY RD 00170 9315 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00170   9315   W MIDLAND, TEXAS',
#   '2021_building_value': 443110.0,
#   '2021_land_value': 10800.0,
#   '2021_total_value': 131900.0,
#   'land_acre': 0.9,
#   'land_sqft': 39204.0,
#   'est_tax': 1415.59,
#   'total_sqft': 4520.0,
#   '$_per_building_sqft': 98.0,
#   '$_per_total_value_sqft': 29.2,
#   'lat': 32.0424758,
#   'lng': -102.196797},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fbd'),
#   'owner': 'JOHNSON STEVEN W',
#   'address_1': '9205 W COUNTY RD 174MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00174 9205 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00174   9205   W MIDLAND, TEXAS',
#   '2021_building_value': 76940.0,
#   '2021_land_value': 28440.0,
#   '2021_total_value': 105380.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 1094.91,
#   'total_sqft': 1266.0,
#   '$_per_building_sqft': 60.8,
#   '$_per_total_value_sqft': 83.2,
#   'lat': 31.9191076,
#   'lng': -102.193357},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fbe'),
#   'owner': 'RAMOS JUAN A ET AL',
#   'address_1': '9404 W COUNTY RD 174 UNIT EMIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00174 9404 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00174   9404   W MIDLAND, TEXAS',
#   '2021_building_value': 42060.0,
#   '2021_land_value': 28440.0,
#   '2021_total_value': 70500.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 969.35,
#   'total_sqft': 1300.0,
#   '$_per_building_sqft': 32.4,
#   '$_per_total_value_sqft': 54.2,
#   'lat': 32.04655220000001,
#   'lng': -102.1954476},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fbf'),
#   'owner': 'NORTON MATT',
#   'address_1': '5610 E COUNTY RD 00120MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 01135 4007 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01135   4007   S MIDLAND, TEXAS',
#   '2021_building_value': 595500.0,
#   '2021_land_value': 32000.0,
#   '2021_total_value': 627500.0,
#   'land_acre': 18.0,
#   'land_sqft': 784080.0,
#   'est_tax': 8526.7,
#   'total_sqft': 3297.0,
#   '$_per_building_sqft': 180.6,
#   '$_per_total_value_sqft': 190.3,
#   'lat': 32.0038367,
#   'lng': -102.0653984},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc0'),
#   'owner': 'BILL RUDY',
#   'address_1': '2408 E COUNTY ROAD 140MIDLAND, TX 79706 7108',
#   'address_2': 'COUNTY RD 00140 2408 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00140   2408   E MIDLAND, TEXAS',
#   '2021_building_value': 421950.0,
#   '2021_land_value': 60000.0,
#   '2021_total_value': 481950.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 4067.86,
#   'total_sqft': 3919.0,
#   '$_per_building_sqft': 107.7,
#   '$_per_total_value_sqft': 123.0,
#   'lat': 31.9204168,
#   'lng': -102.0970267},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc1'),
#   'owner': 'SOMERS & WATSON INVESTMENTS LLC',
#   'address_1': 'PO BOX 8995MIDLAND, TX 79708',
#   'address_2': 'COUNTY RD 01140 4912 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01140   4912   S MIDLAND, TEXAS',
#   '2021_building_value': 158350.0,
#   '2021_land_value': 22800.0,
#   '2021_total_value': 181150.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 2545.09,
#   'total_sqft': 2015.0,
#   '$_per_building_sqft': 78.6,
#   '$_per_total_value_sqft': 89.9,
#   'lat': 32.0031271,
#   'lng': -102.0656771},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc2'),
#   'owner': 'GOFF BRENT',
#   'address_1': '13304 FM RD 307MIDLAND, TX 79706',
#   'address_2': 'FM RD 00307 13304',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'FM RD 00307   13304 MIDLAND, TEXAS',
#   '2021_building_value': 306960.0,
#   '2021_land_value': 12000.0,
#   '2021_total_value': 318960.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 4238.46,
#   'total_sqft': 1844.0,
#   '$_per_building_sqft': 166.5,
#   '$_per_total_value_sqft': 173.0,
#   'lat': 31.9052337,
#   'lng': -102.0322873},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc3'),
#   'owner': 'MATHIS WILLIAM RAY',
#   'address_1': '13300 FM RD 307MIDLAND, TX 79706',
#   'address_2': 'FM RD 00307 13300',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'FM RD 00307   13300 MIDLAND, TEXAS',
#   '2021_building_value': 283140.0,
#   '2021_land_value': 24720.0,
#   '2021_total_value': 307860.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 4090.96,
#   'total_sqft': 2204.0,
#   '$_per_building_sqft': 128.5,
#   '$_per_total_value_sqft': 139.7,
#   'lat': 31.9052337,
#   'lng': -102.0322873},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc4'),
#   'owner': 'KNOWLES NATHAN',
#   'address_1': '2201 SOUTH COUNTY RD 01060MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 01060 2201 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01060   2201   S MIDLAND, TEXAS',
#   '2021_building_value': 264090.0,
#   '2021_land_value': 12000.0,
#   '2021_total_value': 276090.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 2791.8,
#   'total_sqft': 1560.0,
#   '$_per_building_sqft': 169.3,
#   '$_per_total_value_sqft': 177.0,
#   'lat': 31.96169,
#   'lng': -102.123738},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc5'),
#   'owner': 'SOREY DARRELL',
#   'address_1': '2701 S COUNTY ROAD 1060MIDLAND, TX 79706-5603',
#   'address_2': 'COUNTY RD 01060 2701 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01060   2701   S MIDLAND, TEXAS',
#   '2021_building_value': 184940.0,
#   '2021_land_value': 48000.0,
#   '2021_total_value': 101360.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 929.18,
#   'total_sqft': 1674.0,
#   '$_per_building_sqft': 110.5,
#   '$_per_total_value_sqft': 60.5,
#   'lat': 31.9973456,
#   'lng': -102.0779146},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc6'),
#   'owner': 'BALLARD TONY',
#   'address_1': '13200 E COUNTY RD 110MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00110 13200 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00110   13200   E MIDLAND, TEXAS',
#   '2021_building_value': 135330.0,
#   '2021_land_value': 25560.0,
#   '2021_total_value': 160890.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 1543.4,
#   'total_sqft': 1960.0,
#   '$_per_building_sqft': 69.0,
#   '$_per_total_value_sqft': 82.1,
#   'lat': 32.0251636,
#   'lng': -101.8414659},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc7'),
#   'owner': 'BRANAM KIMBERLY',
#   'address_1': '13400 E COUNTY RD 110MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00110 13400 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00110   13400   E MIDLAND, TEXAS',
#   '2021_building_value': 220820.0,
#   '2021_land_value': 52860.0,
#   '2021_total_value': 273680.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 2868.16,
#   'total_sqft': 1548.0,
#   '$_per_building_sqft': 142.6,
#   '$_per_total_value_sqft': 176.8,
#   'lat': 32.0251636,
#   'lng': -101.8414659},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc8'),
#   'owner': 'HOWARD DWAIN',
#   'address_1': '13109 E COUNTY RD 113MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00113 13109 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00113   13109   E MIDLAND, TEXAS',
#   '2021_building_value': 242880.0,
#   '2021_land_value': 24000.0,
#   '2021_total_value': 267960.0,
#   'land_acre': 2.0,
#   'land_sqft': 87120.0,
#   'est_tax': 2704.03,
#   'total_sqft': 1820.0,
#   '$_per_building_sqft': 133.5,
#   '$_per_total_value_sqft': 147.2,
#   'lat': 31.9736391,
#   'lng': -102.0443833},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fc9'),
#   'owner': 'BROOKS LANCE',
#   'address_1': '13009 E COUNTY RD 113MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00113 13009 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00113   13009   E MIDLAND, TEXAS',
#   '2021_building_value': 229030.0,
#   '2021_land_value': 23520.0,
#   '2021_total_value': 252550.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 3355.97,
#   'total_sqft': 2198.0,
#   '$_per_building_sqft': 104.2,
#   '$_per_total_value_sqft': 114.9,
#   'lat': 31.9736391,
#   'lng': -102.0443833},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fca'),
#   'owner': 'LEWIS RICHARD W',
#   'address_1': '13007 E COUNTY ROAD 113MIDLAND, TX 79706-5706',
#   'address_2': 'COUNTY RD 00113 13007 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00113   13007   E MIDLAND, TEXAS',
#   '2021_building_value': 154060.0,
#   '2021_land_value': 23520.0,
#   '2021_total_value': 177580.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 1724.78,
#   'total_sqft': 1400.0,
#   '$_per_building_sqft': 110.0,
#   '$_per_total_value_sqft': 126.8,
#   'lat': 31.9736391,
#   'lng': -102.0443833},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fcb'),
#   'owner': 'MOSES STEPHANIE M',
#   'address_1': '2516 S COUNTY RD 1058MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 01058 2516 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01058   2516   S MIDLAND, TEXAS',
#   '2021_building_value': 146410.0,
#   '2021_land_value': 25200.0,
#   '2021_total_value': 171610.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 1661.96,
#   'total_sqft': 1678.0,
#   '$_per_building_sqft': 87.3,
#   '$_per_total_value_sqft': 102.3,
#   'lat': 32.0251636,
#   'lng': -101.8414659},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fcc'),
#   'owner': 'HENDERSON RONALD J',
#   'address_1': '2606 S COUNTY ROAD 1058MIDLAND, TX 79706-5702',
#   'address_2': 'COUNTY RD 01058 2606 S',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 01058   2606   S MIDLAND, TEXAS',
#   '2021_building_value': 172370.0,
#   '2021_land_value': 25200.0,
#   '2021_total_value': 195900.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 990.21,
#   'total_sqft': 1746.0,
#   '$_per_building_sqft': 98.7,
#   '$_per_total_value_sqft': 112.2,
#   'lat': 31.9973456,
#   'lng': -102.0779146},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fcd'),
#   'owner': 'WALSER ROY',
#   'address_1': '13101 E COUNTY RD 113MIDLAND, TX 79706-5706',
#   'address_2': 'COUNTY RD 00113 13101 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00113   13101   E MIDLAND, TEXAS',
#   '2021_building_value': 213880.0,
#   '2021_land_value': 23520.0,
#   '2021_total_value': 237400.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 2388.12,
#   'total_sqft': 1631.0,
#   '$_per_building_sqft': 131.1,
#   '$_per_total_value_sqft': 145.6,
#   'lat': 31.9736391,
#   'lng': -102.0443833},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fce'),
#   'owner': 'LAND DUSTY',
#   'address_1': '13401 E COUNTY RD 120MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00120 13401 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00120   13401   E MIDLAND, TEXAS',
#   '2021_building_value': 282680.0,
#   '2021_land_value': 2000.0,
#   '2021_total_value': 286300.0,
#   'land_acre': 9.0,
#   'land_sqft': 392040.0,
#   'est_tax': 2908.59,
#   'total_sqft': 1768.0,
#   '$_per_building_sqft': 159.9,
#   '$_per_total_value_sqft': 161.9,
#   'lat': 31.964647,
#   'lng': -102.0374919},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fcf'),
#   'owner': 'LR RANCH LLC',
#   'address_1': '4209 FERNCLIFFMIDLAND, TX 79707',
#   'address_2': 'COUNTY RD 00120 13501 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00120   13501   E MIDLAND, TEXAS',
#   '2021_building_value': 167620.0,
#   '2021_land_value': 2000.0,
#   '2021_total_value': 173430.0,
#   'land_acre': 21.149,
#   'land_sqft': 921250.0,
#   'est_tax': 2304.6,
#   'total_sqft': 672.0,
#   '$_per_building_sqft': 249.4,
#   '$_per_total_value_sqft': 258.1,
#   'lat': 31.964647,
#   'lng': -102.0374919},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd0'),
#   'owner': 'JCF RANCH LP',
#   'address_1': '4400 E COUNTY RD 190MIDLAND, TX 79706',
#   'address_2': 'COUNTY RD 00190 4400 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00190   4400   E MIDLAND, TEXAS',
#   '2021_building_value': 76780.0,
#   '2021_land_value': 500.0,
#   '2021_total_value': 77280.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 1062.58,
#   'total_sqft': 2544.0,
#   '$_per_building_sqft': 30.2,
#   '$_per_total_value_sqft': 30.4,
#   'lat': 31.8666828,
#   'lng': -102.067644},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd1'),
#   'owner': 'J B H FAMILY LP',
#   'address_1': 'JAY B HORTONPO BOX 50428MIDLAND, TX 79710 0428',
#   'address_2': 'COUNTY RD 00190 5500 E',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'COUNTY RD 00190   5500   E MIDLAND, TEXAS',
#   '2021_building_value': 375630.0,
#   '2021_land_value': 800.0,
#   '2021_total_value': 442920.0,
#   'land_acre': 349.0,
#   'land_sqft': 15202440.0,
#   'est_tax': 6090.01,
#   'total_sqft': 4008.0,
#   '$_per_building_sqft': 93.7,
#   '$_per_total_value_sqft': 110.5,
#   'lat': 32.011972,
#   'lng': -101.9840485},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd2'),
#   'owner': 'GIFFORD JOE N',
#   'address_1': '529 SOLOMON LNMIDLAND, TX 79705 3038',
#   'address_2': 'SOLOMON LN 529',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'SOLOMON LN   529 MIDLAND, TEXAS',
#   '2021_building_value': 793320.0,
#   '2021_land_value': 68300.0,
#   '2021_total_value': 861620.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 8121.04,
#   'total_sqft': 4766.0,
#   '$_per_building_sqft': 166.5,
#   '$_per_total_value_sqft': 180.8,
#   'lat': 32.0492672,
#   'lng': -102.0929185},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd3'),
#   'owner': 'GIFFORD T K ET AL',
#   'address_1': 'PO BOX 51187MIDLAND, TX 79710-1187',
#   'address_2': 'SOLOMON LN 27',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'SOLOMON LN   27 MIDLAND, TEXAS',
#   '2021_building_value': 108190.0,
#   '2021_land_value': 67300.0,
#   '2021_total_value': 175490.0,
#   'land_acre': 0.83,
#   'land_sqft': 36154.0,
#   'est_tax': 3057.32,
#   'total_sqft': 1110.0,
#   '$_per_building_sqft': 97.5,
#   '$_per_total_value_sqft': 158.1,
#   'lat': 32.0485539,
#   'lng': -102.092606},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd4'),
#   'owner': 'PETREE JESSE WAYNE',
#   'address_1': '519 SOLOMON LNMIDLAND, TX 79705-3037',
#   'address_2': 'SOLOMON LN 519',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'SOLOMON LN   519 MIDLAND, TEXAS',
#   '2021_building_value': 298950.0,
#   '2021_land_value': 72140.0,
#   '2021_total_value': 371090.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 5477.73,
#   'total_sqft': 2546.0,
#   '$_per_building_sqft': 117.4,
#   '$_per_total_value_sqft': 145.8,
#   'lat': 32.0497992,
#   'lng': -102.0919364},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd5'),
#   'owner': 'PETREE JESSE',
#   'address_1': '519 SOLOMON LNMIDLAND, TX 79705',
#   'address_2': 'SOLOMON LN 503',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'SOLOMON LN   503 MIDLAND, TEXAS',
#   '2021_building_value': 375130.0,
#   '2021_land_value': 70040.0,
#   '2021_total_value': 445170.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 7755.56,
#   'total_sqft': 3064.0,
#   '$_per_building_sqft': 122.4,
#   '$_per_total_value_sqft': 145.3,
#   'lat': 32.0500559,
#   'lng': -102.0910883},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd6'),
#   'owner': 'SPENCE MERLE L',
#   'address_1': 'PO BOX 61528MIDLAND, TX 79711',
#   'address_2': 'SOLOMON LN 502',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'SOLOMON LN   502 MIDLAND, TEXAS',
#   '2021_building_value': 1231360.0,
#   '2021_land_value': 109250.0,
#   '2021_total_value': 1227370.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 19188.65,
#   'total_sqft': 6789.0,
#   '$_per_building_sqft': 181.4,
#   '$_per_total_value_sqft': 180.8,
#   'lat': 32.0508517,
#   'lng': -102.090999},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd7'),
#   'owner': 'FIETZ DAVID LEE',
#   'address_1': '414 SOLOMON LNMIDLAND, TX 79705',
#   'address_2': 'SOLOMON LN 414',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'SOLOMON LN   414 MIDLAND, TEXAS',
#   '2021_building_value': 1284030.0,
#   '2021_land_value': 129860.0,
#   '2021_total_value': 1413890.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 22956.29,
#   'total_sqft': 4606.0,
#   '$_per_building_sqft': 278.8,
#   '$_per_total_value_sqft': 307.0,
#   'lat': 32.0511084,
#   'lng': -102.0899449},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd8'),
#   'owner': 'DALE CECIL E III',
#   'address_1': '320 SOLOMON LNMIDLAND, TX 79705',
#   'address_2': 'SOLOMON LN 320',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'SOLOMON LN   320 MIDLAND, TEXAS',
#   '2021_building_value': 271510.0,
#   '2021_land_value': 95830.0,
#   '2021_total_value': 367340.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 5752.11,
#   'total_sqft': 2862.0,
#   '$_per_building_sqft': 94.9,
#   '$_per_total_value_sqft': 128.4,
#   'lat': 32.0511843,
#   'lng': -102.0884546},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fd9'),
#   'owner': 'LILLIS CHRIS M',
#   'address_1': '5115 POLO CLUB RDMIDLAND, TX 79705',
#   'address_2': 'POLO CLUB RD 5115',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'POLO CLUB RD   5115 MIDLAND, TEXAS',
#   '2021_building_value': 414600.0,
#   '2021_land_value': 128880.0,
#   '2021_total_value': 543480.0,
#   'land_acre': 3.296,
#   'land_sqft': 143569.0,
#   'est_tax': 9468.28,
#   'total_sqft': 2541.0,
#   '$_per_building_sqft': 163.2,
#   '$_per_total_value_sqft': 213.9,
#   'lat': 32.0466387,
#   'lng': -102.112764},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fda'),
#   'owner': 'OWEN RYAN',
#   'address_1': '5207 POLO CLUB RDMIDLAND, TX 79705',
#   'address_2': 'POLO CLUB RD 5207',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'POLO CLUB RD   5207 MIDLAND, TEXAS',
#   '2021_building_value': 445670.0,
#   '2021_land_value': 64500.0,
#   '2021_total_value': 510170.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 8088.17,
#   'total_sqft': 3454.0,
#   '$_per_building_sqft': 129.0,
#   '$_per_total_value_sqft': 147.7,
#   'lat': 32.0483613,
#   'lng': -102.1127406},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fdb'),
#   'owner': 'HOPKINS JOSEPH',
#   'address_1': '5305 POLO CLUB RDMIDLAND, TX 79705',
#   'address_2': 'POLO CLUB RD 5305',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'POLO CLUB RD   5305 MIDLAND, TEXAS',
#   '2021_building_value': 284100.0,
#   '2021_land_value': 60000.0,
#   '2021_total_value': 344100.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 5404.0,
#   'total_sqft': 2206.0,
#   '$_per_building_sqft': 128.8,
#   '$_per_total_value_sqft': 156.0,
#   'lat': 32.0495413,
#   'lng': -102.112675},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fdc'),
#   'owner': 'WILLIAMS CLAYTON W JR',
#   'address_1': '6 DESTA DR STE 1100MIDLAND, TX 79705-5510',
#   'address_2': 'CARDINAL LN 1716',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   1716 MIDLAND, TEXAS',
#   '2021_building_value': 1465450.0,
#   '2021_land_value': 219600.0,
#   '2021_total_value': 1685050.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 17954.95,
#   'total_sqft': 14246.0,
#   '$_per_building_sqft': 102.9,
#   '$_per_total_value_sqft': 118.3,
#   'lat': 32.0477765,
#   'lng': -102.1101105},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fdd'),
#   'owner': 'MAGRUDER ELAINE',
#   'address_1': 'PO BOX 11250MIDLAND, TX 79702',
#   'address_2': 'POLO CLUB RD 5300',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'POLO CLUB RD   5300 MIDLAND, TEXAS',
#   '2021_building_value': 176080.0,
#   '2021_land_value': 56400.0,
#   '2021_total_value': 232480.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 4050.17,
#   'total_sqft': 1761.0,
#   '$_per_building_sqft': 100.0,
#   '$_per_total_value_sqft': 132.0,
#   'lat': 32.0492254,
#   'lng': -102.1114761},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fde'),
#   'owner': 'GURGEVICH JENNIFER A',
#   'address_1': 'PO BOX 51662MIDLAND, TX 79710',
#   'address_2': 'BLUEBIRD BRANCH CT 5000',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'BLUEBIRD BRANCH CT   5000 MIDLAND, TEXAS',
#   '2021_building_value': 469850.0,
#   '2021_land_value': 20000.0,
#   '2021_total_value': 489850.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 7755.82,
#   'total_sqft': 2896.0,
#   '$_per_building_sqft': 162.2,
#   '$_per_total_value_sqft': 169.1,
#   'lat': 32.0414308,
#   'lng': -102.1213357},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fdf'),
#   'owner': 'BEAUCHAMP PAXTON L',
#   'address_1': '5200 N MIDKIFF RDMIDLAND, TX 79705',
#   'address_2': 'MIDKIFF RD 5200 N',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'MIDKIFF RD   5200   N MIDLAND, TEXAS',
#   '2021_building_value': 283970.0,
#   '2021_land_value': 60000.0,
#   '2021_total_value': 343970.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 5098.7,
#   'total_sqft': 2626.0,
#   '$_per_building_sqft': 108.1,
#   '$_per_total_value_sqft': 131.0,
#   'lat': 32.0428455,
#   'lng': -102.1313605},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe0'),
#   'owner': 'MITCHELL LEWIS',
#   'address_1': '2500 BLUEBIRD LNMIDLAND, TX 79705',
#   'address_2': 'BLUEBIRD LN 2500',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'BLUEBIRD LN   2500 MIDLAND, TEXAS',
#   '2021_building_value': 1292430.0,
#   '2021_land_value': 422100.0,
#   '2021_total_value': 1101820.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 16315.79,
#   'total_sqft': 5300.0,
#   '$_per_building_sqft': 243.9,
#   '$_per_total_value_sqft': 207.9,
#   'lat': 32.0463289,
#   'lng': -102.1217898},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe1'),
#   'owner': 'EVANS BARTON B',
#   'address_1': 'PO BOX 9430MIDLAND, TX 79708-9430',
#   'address_2': 'BLUEBIRD LN 2310',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'BLUEBIRD LN   2310 MIDLAND, TEXAS',
#   '2021_building_value': 474290.0,
#   '2021_land_value': 132300.0,
#   '2021_total_value': 606590.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 7904.64,
#   'total_sqft': 5277.0,
#   '$_per_building_sqft': 89.9,
#   '$_per_total_value_sqft': 114.9,
#   'lat': 32.0452184,
#   'lng': -102.1173422},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe2'),
#   'owner': 'GARDAPHE CHASE',
#   'address_1': '1 KIMSEY WAYMIDLAND, TX 79705',
#   'address_2': 'KIMSEY WAY 1',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'KIMSEY WAY   1 MIDLAND, TEXAS',
#   '2021_building_value': 681570.0,
#   '2021_land_value': 210600.0,
#   '2021_total_value': 842770.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 13720.54,
#   'total_sqft': 4743.0,
#   '$_per_building_sqft': 143.7,
#   '$_per_total_value_sqft': 177.7,
#   'lat': 32.0455203,
#   'lng': -102.1162725},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe3'),
#   'owner': 'EVANS ROBERT M',
#   'address_1': '3509 MOCKINGBIRD LNMIDLAND, TX 79707',
#   'address_2': 'MOCKINGBIRD LN 3509',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'MOCKINGBIRD LN   3509 MIDLAND, TEXAS',
#   '2021_building_value': 737800.0,
#   '2021_land_value': 30000.0,
#   '2021_total_value': 768710.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 12317.69,
#   'total_sqft': 4486.0,
#   '$_per_building_sqft': 164.5,
#   '$_per_total_value_sqft': 171.4,
#   'lat': 32.045472,
#   'lng': -102.1383146},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe4'),
#   'owner': 'JONES CHARLES W',
#   'address_1': '4113 MOCKINGBIRD LNMIDLAND, TX 79707',
#   'address_2': 'MOCKINGBIRD LN 4113',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'MOCKINGBIRD LN   4113 MIDLAND, TEXAS',
#   '2021_building_value': 1849530.0,
#   '2021_land_value': 72450.0,
#   '2021_total_value': 1921980.0,
#   'land_acre': 2.27,
#   'land_sqft': 98881.0,
#   'est_tax': 33483.9,
#   'total_sqft': 7743.0,
#   '$_per_building_sqft': 238.9,
#   '$_per_total_value_sqft': 248.2,
#   'lat': 32.0442259,
#   'lng': -102.1467009},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe5'),
#   'owner': 'HAMBLETON JOYCE',
#   'address_1': '4301 MOCKINGBIRD LNMIDLAND, TX 79707',
#   'address_2': 'MOCKINGBIRD LN 4301',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'MOCKINGBIRD LN   4301 MIDLAND, TEXAS',
#   '2021_building_value': 465630.0,
#   '2021_land_value': 100800.0,
#   '2021_total_value': 566430.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 9111.74,
#   'total_sqft': 2641.0,
#   '$_per_building_sqft': 176.3,
#   '$_per_total_value_sqft': 214.5,
#   'lat': 32.0439549,
#   'lng': -102.1486313},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe6'),
#   'owner': 'HUBBARD ORMAN J',
#   'address_1': 'PO BOX 512MIDLAND, TX 79702-0512',
#   'address_2': 'CARDINAL LN 4222',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   4222 MIDLAND, TEXAS',
#   '2021_building_value': 360540.0,
#   '2021_land_value': 76200.0,
#   '2021_total_value': 436740.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 4500.66,
#   'total_sqft': 2996.0,
#   '$_per_building_sqft': 120.3,
#   '$_per_total_value_sqft': 145.8,
#   'lat': 32.0414085,
#   'lng': -102.1475718},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe7'),
#   'owner': 'RYON LOU DENA',
#   'address_1': '4204 CARDINAL LNMIDLAND, TX 79707-1935',
#   'address_2': 'CARDINAL LN 4204',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   4204 MIDLAND, TEXAS',
#   '2021_building_value': 232610.0,
#   '2021_land_value': 45000.0,
#   '2021_total_value': 277610.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 3997.36,
#   'total_sqft': 2204.0,
#   '$_per_building_sqft': 105.5,
#   '$_per_total_value_sqft': 126.0,
#   'lat': 32.0414728,
#   'lng': -102.1464553},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe8'),
#   'owner': 'FLETCHER CLIFTON A',
#   'address_1': '3914 CARDINAL LNMIDLAND, TX 79707-1929',
#   'address_2': 'CARDINAL LN 3914',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3914 MIDLAND, TEXAS',
#   '2021_building_value': 172040.0,
#   '2021_land_value': 231900.0,
#   '2021_total_value': 403940.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 3167.83,
#   'total_sqft': 1791.0,
#   '$_per_building_sqft': 96.1,
#   '$_per_total_value_sqft': 225.5,
#   'lat': 32.0421992,
#   'lng': -102.1430163},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fe9'),
#   'owner': 'JOHNSTON JEFFREY &',
#   'address_1': 'SHAWN JOHNSTON3708 CARDINAL LNMIDLAND, TX 79707',
#   'address_2': 'CARDINAL LN 3708',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3708 MIDLAND, TEXAS',
#   '2021_building_value': 500530.0,
#   '2021_land_value': 53400.0,
#   '2021_total_value': 553930.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 9650.33,
#   'total_sqft': 3678.0,
#   '$_per_building_sqft': 136.1,
#   '$_per_total_value_sqft': 150.6,
#   'lat': 32.0425641,
#   'lng': -102.1401364},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fea'),
#   'owner': 'WALL MATTHEW',
#   'address_1': '3704 CARDINAL LNMIDLAND, TX 79707',
#   'address_2': 'CARDINAL LN 3704',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3704 MIDLAND, TEXAS',
#   '2021_building_value': 767980.0,
#   '2021_land_value': 117300.0,
#   '2021_total_value': 885280.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 14223.27,
#   'total_sqft': 3632.0,
#   '$_per_building_sqft': 211.4,
#   '$_per_total_value_sqft': 243.7,
#   'lat': 32.0427477,
#   'lng': -102.1395022},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4feb'),
#   'owner': 'JOHNSON MATTHEW LYONS',
#   'address_1': '3602 CARDINAL LNMIDLAND, TX 79707',
#   'address_2': 'CARDINAL LN 3602',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3602 MIDLAND, TEXAS',
#   '2021_building_value': 1185400.0,
#   '2021_land_value': 120000.0,
#   '2021_total_value': 579600.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 9319.68,
#   'total_sqft': 4572.0,
#   '$_per_building_sqft': 259.3,
#   '$_per_total_value_sqft': 126.8,
#   'lat': 32.0430816,
#   'lng': -102.1378626},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fec'),
#   'owner': 'GRIGSBY JEFFERY',
#   'address_1': '3508 CARDINAL LNMIDLAND, TX 79707',
#   'address_2': 'CARDINAL LN 3508',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3508 MIDLAND, TEXAS',
#   '2021_building_value': 661710.0,
#   '2021_land_value': 118200.0,
#   '2021_total_value': 753270.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 12158.21,
#   'total_sqft': 4178.0,
#   '$_per_building_sqft': 158.4,
#   '$_per_total_value_sqft': 180.3,
#   'lat': 32.043055,
#   'lng': -102.1370753},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fed'),
#   'owner': 'HURT ALEX B',
#   'address_1': '3504 CARDINAL LNMIDLAND, TX 79707',
#   'address_2': 'CARDINAL LN 3504',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3504 MIDLAND, TEXAS',
#   '2021_building_value': 1237910.0,
#   '2021_land_value': 125100.0,
#   '2021_total_value': 1232320.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 20000.65,
#   'total_sqft': 5978.0,
#   '$_per_building_sqft': 207.1,
#   '$_per_total_value_sqft': 206.1,
#   'lat': 32.0432765,
#   'lng': -102.1361605},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fee'),
#   'owner': 'YATES JAMES H',
#   'address_1': '3303 CADINAL LNMIDLAND, TX 79707-1811',
#   'address_2': 'CARDINAL LN 3303',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3303 MIDLAND, TEXAS',
#   '2021_building_value': 501120.0,
#   '2021_land_value': 80400.0,
#   '2021_total_value': 570370.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 8012.08,
#   'total_sqft': 2877.0,
#   '$_per_building_sqft': 174.2,
#   '$_per_total_value_sqft': 198.3,
#   'lat': 32.0429044,
#   'lng': -102.1330128},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fef'),
#   'owner': 'GJW PROPERTIES LLC',
#   'address_1': '6410 SEQUOIAMIDLAND, TX 79707',
#   'address_2': 'MIDKIFF RD 5201 N',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'MIDKIFF RD   5201   N MIDLAND, TEXAS',
#   '2021_building_value': 259110.0,
#   '2021_land_value': 9600.0,
#   '2021_total_value': 268710.0,
#   'land_acre': 0.32,
#   'land_sqft': 13939.0,
#   'est_tax': 4681.35,
#   'total_sqft': 1912.0,
#   '$_per_building_sqft': 135.5,
#   '$_per_total_value_sqft': 140.5,
#   'lat': 32.042121,
#   'lng': -102.1325216},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff0'),
#   'owner': 'MAGUIRE CHRISTOPHER',
#   'address_1': '3307 CARDINAL LNMIDLAND, TX 79707',
#   'address_2': 'CARDINAL LN 3307',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3307 MIDLAND, TEXAS',
#   '2021_building_value': 1171650.0,
#   '2021_land_value': 60000.0,
#   '2021_total_value': 488450.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 7764.9,
#   'total_sqft': 5024.0,
#   '$_per_building_sqft': 233.2,
#   '$_per_total_value_sqft': 97.2,
#   'lat': 32.0425927,
#   'lng': -102.1337496},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff1'),
#   'owner': 'NOLEN KENNETH',
#   'address_1': '3707 CARDINAL LNMIDLAND, TX 79707-1819',
#   'address_2': 'CARDINAL LN 3707',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3707 MIDLAND, TEXAS',
#   '2021_building_value': 355760.0,
#   '2021_land_value': 168000.0,
#   '2021_total_value': 522970.0,
#   'land_acre': 4.6,
#   'land_sqft': 200376.0,
#   'est_tax': 6402.4,
#   'total_sqft': 3941.0,
#   '$_per_building_sqft': 90.3,
#   '$_per_total_value_sqft': 132.7,
#   'lat': 32.0411123,
#   'lng': -102.1391086},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff2'),
#   'owner': 'FREDERICK RONALD M',
#   'address_1': 'PO BOX 1501MIDLAND, TX 79702 1501',
#   'address_2': 'CARDINAL LN 3803',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3803 MIDLAND, TEXAS',
#   '2021_building_value': 473740.0,
#   '2021_land_value': 87000.0,
#   '2021_total_value': 552910.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 8847.96,
#   'total_sqft': 3239.0,
#   '$_per_building_sqft': 146.3,
#   '$_per_total_value_sqft': 170.7,
#   'lat': 32.0409846,
#   'lng': -102.1402028},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff3'),
#   'owner': 'HARVEY P JAMES',
#   'address_1': '3811 CARDINAL LNMIDLAND, TX 79707-1927',
#   'address_2': 'CARDINAL LN 3811',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3811 MIDLAND, TEXAS',
#   '2021_building_value': 425180.0,
#   '2021_land_value': 80700.0,
#   '2021_total_value': 505880.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 8072.06,
#   'total_sqft': 3507.0,
#   '$_per_building_sqft': 121.2,
#   '$_per_total_value_sqft': 144.2,
#   'lat': 32.0414384,
#   'lng': -102.1411629},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff4'),
#   'owner': 'NEAL JULIE',
#   'address_1': '3905 CARDINAL LNMIDLAND, TX 79707',
#   'address_2': 'CARDINAL LN 3905',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   3905 MIDLAND, TEXAS',
#   '2021_building_value': 533800.0,
#   '2021_land_value': 91200.0,
#   '2021_total_value': 625000.0,
#   'land_acre': 3.04,
#   'land_sqft': 132422.0,
#   'est_tax': 9966.26,
#   'total_sqft': 2220.0,
#   '$_per_building_sqft': 240.5,
#   '$_per_total_value_sqft': 281.5,
#   'lat': 32.0410914,
#   'lng': -102.1418105},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff5'),
#   'owner': 'JOCHIMSEN ALAN & MARCHETA',
#   'address_1': '4209 CARDINAL LNMIDLAND, TX 79707 1935',
#   'address_2': 'CARDINAL LN 4209',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   4209 MIDLAND, TEXAS',
#   '2021_building_value': 505650.0,
#   '2021_land_value': 96000.0,
#   '2021_total_value': 601650.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 8655.39,
#   'total_sqft': 4086.0,
#   '$_per_building_sqft': 123.8,
#   '$_per_total_value_sqft': 147.2,
#   'lat': 32.0409352,
#   'lng': -102.1469725},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff6'),
#   'owner': 'CAGE JAME TODD',
#   'address_1': '4221 CARDINAL LNMIDLAND, TX 79707',
#   'address_2': 'CARDINAL LN 4221',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CARDINAL LN   4221 MIDLAND, TEXAS',
#   '2021_building_value': 878470.0,
#   '2021_land_value': 96000.0,
#   '2021_total_value': 974470.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 15752.39,
#   'total_sqft': 3998.0,
#   '$_per_building_sqft': 219.7,
#   '$_per_total_value_sqft': 243.7,
#   'lat': 32.0408798,
#   'lng': -102.1474525},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff7'),
#   'owner': 'BRADY BRUCE M III',
#   'address_1': '3500 BLUEBIRD LNMIDLAND, TX 79707',
#   'address_2': 'BLUEBIRD LN 3500',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'BLUEBIRD LN   3500 MIDLAND, TEXAS',
#   '2021_building_value': 761450.0,
#   '2021_land_value': 42600.0,
#   '2021_total_value': 806140.0,
#   'land_acre': 1.42,
#   'land_sqft': 61855.0,
#   'est_tax': 12574.36,
#   'total_sqft': 4862.0,
#   '$_per_building_sqft': 156.6,
#   '$_per_total_value_sqft': 165.8,
#   'lat': 32.0398772,
#   'lng': -102.1384276},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff8'),
#   'owner': 'DITTO WILLIAM H',
#   'address_1': '3410 BLUEBIRD LNMIDLAND, TX 79707',
#   'address_2': 'BLUEBIRD LN 3410',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'BLUEBIRD LN   3410 MIDLAND, TEXAS',
#   '2021_building_value': 802895.0,
#   '2021_land_value': 120000.0,
#   '2021_total_value': 922895.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 14934.43,
#   'total_sqft': 5632.0,
#   '$_per_building_sqft': 142.6,
#   '$_per_total_value_sqft': 163.9,
#   'lat': 32.0403489,
#   'lng': -102.1370543},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ff9'),
#   'owner': 'DOKE BEN W',
#   'address_1': '3400 BLUEBIRD LNMIDLAND, TX 79707',
#   'address_2': 'BLUEBIRD LN 3400',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'BLUEBIRD LN   3400 MIDLAND, TEXAS',
#   '2021_building_value': 1071610.0,
#   '2021_land_value': 171000.0,
#   '2021_total_value': 1242610.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 20217.89,
#   'total_sqft': 5517.0,
#   '$_per_building_sqft': 194.2,
#   '$_per_total_value_sqft': 225.2,
#   'lat': 32.0406602,
#   'lng': -102.1358709},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ffa'),
#   'owner': 'DWYER MISSY',
#   'address_1': '3310 BLUEBIRD LNMIDLAND, TX 79701',
#   'address_2': 'BLUEBIRD LN 3310',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'BLUEBIRD LN   3310 MIDLAND, TEXAS',
#   '2021_building_value': 794400.0,
#   '2021_land_value': 164700.0,
#   '2021_total_value': 959100.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 15430.63,
#   'total_sqft': 4044.0,
#   '$_per_building_sqft': 196.4,
#   '$_per_total_value_sqft': 237.2,
#   'lat': 32.0406696,
#   'lng': -102.1346428},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ffb'),
#   'owner': 'HOME LINE BAPTIST CHURCH',
#   'address_1': '3302 BLUEBIRD LNMIDLAND, TX 79707 2412',
#   'address_2': 'BLUEBIRD LN 3302',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'BLUEBIRD LN   3302 MIDLAND, TEXAS',
#   '2021_building_value': 205440.0,
#   '2021_land_value': 144390.0,
#   '2021_total_value': 349830.0,
#   'land_acre': 4.813,
#   'land_sqft': 209651.0,
#   'est_tax': 0.0,
#   'total_sqft': 2045.0,
#   '$_per_building_sqft': 100.5,
#   '$_per_total_value_sqft': 171.1,
#   'lat': 32.0408091,
#   'lng': -102.1325216},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ffc'),
#   'owner': 'BURROW RYAN',
#   'address_1': '4400 MOCKINGBIRD LNMIDLAND, TX 79707',
#   'address_2': 'MOCKINGBIRD LN 4400',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'MOCKINGBIRD LN   4400 MIDLAND, TEXAS',
#   '2021_building_value': 245390.0,
#   '2021_land_value': 20000.0,
#   '2021_total_value': 265390.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 4623.5,
#   'total_sqft': 1725.0,
#   '$_per_building_sqft': 142.3,
#   '$_per_total_value_sqft': 153.8,
#   'lat': 32.0441693,
#   'lng': -102.1508992},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ffd'),
#   'owner': 'LILLY ALTON DON',
#   'address_1': '4406 MOCKINGBIRDMIDLAND, TX 79707',
#   'address_2': 'MOCKINGBIRD LN 4406',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'MOCKINGBIRD LN   4406 MIDLAND, TEXAS',
#   '2021_building_value': 378780.0,
#   '2021_land_value': 20000.0,
#   '2021_total_value': 398780.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 3288.92,
#   'total_sqft': 2360.0,
#   '$_per_building_sqft': 160.5,
#   '$_per_total_value_sqft': 169.0,
#   'lat': 32.0432528,
#   'lng': -102.1547181},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4ffe'),
#   'owner': 'HENSON RANDY & DEBRA HENSON',
#   'address_1': '2012 WAREHOUSE RDMIDLAND, TX 79706',
#   'address_2': 'MOCKINGBIRD LN 4500',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'MOCKINGBIRD LN   4500 MIDLAND, TEXAS',
#   '2021_building_value': 510000.0,
#   '2021_land_value': 30000.0,
#   '2021_total_value': 540000.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 8208.44,
#   'total_sqft': 4728.0,
#   '$_per_building_sqft': 107.9,
#   '$_per_total_value_sqft': 114.2,
#   'lat': 32.043015,
#   'lng': -102.1556776},
#  {'_id': ObjectId('61e60f8d68822cfcae1f4fff'),
#   'owner': 'MEINER JEFFREY E',
#   'address_1': '14 TATTENHAM CORMIDLAND, TX 79707-1628',
#   'address_2': 'TATTENHAM COR 14',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'TATTENHAM COR   14 MIDLAND, TEXAS',
#   '2021_building_value': 375650.0,
#   '2021_land_value': 22200.0,
#   '2021_total_value': 374630.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 5871.35,
#   'total_sqft': 3083.0,
#   '$_per_building_sqft': 121.8,
#   '$_per_total_value_sqft': 121.5,
#   'lat': 32.0435471,
#   'lng': -102.1567322},
#  {'_id': ObjectId('61e60f8d68822cfcae1f5000'),
#   'owner': 'PRUITT ROGER',
#   'address_1': '4 TATTENHAM CORNERMIDLAND, TX 79707',
#   'address_2': 'TATTENHAM COR 4',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'TATTENHAM COR   4 MIDLAND, TEXAS',
#   '2021_building_value': 514830.0,
#   '2021_land_value': 22000.0,
#   '2021_total_value': 514570.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 8160.13,
#   'total_sqft': 2851.0,
#   '$_per_building_sqft': 180.6,
#   '$_per_total_value_sqft': 180.5,
#   'lat': 32.0445753,
#   'lng': -102.1523508},
#  {'_id': ObjectId('61e60f8d68822cfcae1f5001'),
#   'owner': 'ANDERSON MILTON CARL',
#   'address_1': '2 TATTENHAM CTMIDLAND, TX 79707',
#   'address_2': 'TATTENHAM COR 2',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'TATTENHAM COR   2 MIDLAND, TEXAS',
#   '2021_building_value': 258750.0,
#   '2021_land_value': 20000.0,
#   '2021_total_value': 278750.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 4303.19,
#   'total_sqft': 2124.0,
#   '$_per_building_sqft': 121.8,
#   '$_per_total_value_sqft': 131.2,
#   'lat': 32.0448233,
#   'lng': -102.1511449},
#  {'_id': ObjectId('61e60f8d68822cfcae1f5002'),
#   'owner': 'DAYTON JAMES T JR',
#   'address_1': '#1 TATTENHAM CORNERMIDLAND, TX 79707',
#   'address_2': 'TATTENHAM CT 1',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'TATTENHAM CT   1 MIDLAND, TEXAS',
#   '2021_building_value': 367660.0,
#   '2021_land_value': 20000.0,
#   '2021_total_value': 387660.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 6084.46,
#   'total_sqft': 2468.0,
#   '$_per_building_sqft': 149.0,
#   '$_per_total_value_sqft': 157.1,
#   'lat': 32.0453178,
#   'lng': -102.1514575},
#  {'_id': ObjectId('61e60f8d68822cfcae1f5003'),
#   'owner': 'HERRERA GABRIEL D',
#   'address_1': '#3 TATTENHAM CRMIDLAND, TX 79707',
#   'address_2': 'TATTENHAM COR 3',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'TATTENHAM COR   3 MIDLAND, TEXAS',
#   '2021_building_value': 527930.0,
#   '2021_land_value': 22000.0,
#   '2021_total_value': 549930.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 9580.63,
#   'total_sqft': 4337.0,
#   '$_per_building_sqft': 121.7,
#   '$_per_total_value_sqft': 126.8,
#   'lat': 32.0450621,
#   'lng': -102.1525456},
#  {'_id': ObjectId('61e60f8d68822cfcae1f5004'),
#   'owner': 'LIGHTFOOT CLIFFORD BRENT',
#   'address_1': '5 TATTENHAM CORNERMIDLAND, TX 79707',
#   'address_2': 'TATTENHAM COR 5',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'TATTENHAM COR   5 MIDLAND, TEXAS',
#   '2021_building_value': 350860.0,
#   '2021_land_value': 21000.0,
#   '2021_total_value': 365570.0,
#   'land_acre': 1.0,
#   'land_sqft': 43560.0,
#   'est_tax': 5724.23,
#   'total_sqft': 2373.0,
#   '$_per_building_sqft': 147.9,
#   '$_per_total_value_sqft': 154.1,
#   'lat': 32.0450131,
#   'lng': -102.1527975},
#  {'_id': ObjectId('61e60f8d68822cfcae1f5005'),
#   'owner': 'GARZA DEBRA COLTON',
#   'address_1': '7 TATTENHAM CTMIDLAND, TX 79707',
#   'address_2': 'TATTENHAM COR 7',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'TATTENHAM COR   7 MIDLAND, TEXAS',
#   '2021_building_value': 215590.0,
#   '2021_land_value': 14400.0,
#   '2021_total_value': 229990.0,
#   'land_acre': 0.72,
#   'land_sqft': 31363.0,
#   'est_tax': 3131.62,
#   'total_sqft': 1585.0,
#   '$_per_building_sqft': 136.0,
#   '$_per_total_value_sqft': 145.1,
#   'lat': 32.0448084,
#   'lng': -102.1535568},
#  {'_id': ObjectId('61e60f8d68822cfcae1f5006'),
#   'owner': 'JEFFREYS JOHNNY DARRYL',
# ...
#   '2021_total_value': 171330.0,
#   'land_acre': 0.167,
#   'land_sqft': 7269.0,
#   'est_tax': 2546.27,
#   'total_sqft': 1335.0,
#   '$_per_building_sqft': 120.2,
#   '$_per_total_value_sqft': 128.3,
#   'lat': 31.9920623,
#   'lng': -102.1417659},
#  {'_id': ObjectId('61e60f8e68822cfcae1f537e'),
#   'owner': 'MARQUEZ RAYMOND JR',
#   'address_1': '4701 LAURA DRMIDLAND, TX 79703',
#   'address_2': 'LAURA DR 4701',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4701 MIDLAND, TEXAS',
#   '2021_building_value': 193640.0,
#   '2021_land_value': 10900.0,
#   '2021_total_value': 198880.0,
#   'land_acre': 0.167,
#   'land_sqft': 7269.0,
#   'est_tax': 2996.88,
#   'total_sqft': 1566.0,
#   '$_per_building_sqft': 123.7,
#   '$_per_total_value_sqft': 127.0,
#   'lat': 31.9920795,
#   'lng': -102.1415872},
#  {'_id': ObjectId('61e60f8e68822cfcae1f537f'),
#   'owner': 'MORENO JOSE ANGEL',
#   'address_1': '4700 LAURA DRMIDLAND, TX 79703',
#   'address_2': 'LAURA DR 4700',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4700 MIDLAND, TEXAS',
#   '2021_building_value': 149830.0,
#   '2021_land_value': 10900.0,
#   '2021_total_value': 155030.0,
#   'land_acre': 0.167,
#   'land_sqft': 7269.0,
#   'est_tax': 1976.02,
#   'total_sqft': 1164.0,
#   '$_per_building_sqft': 128.7,
#   '$_per_total_value_sqft': 133.2,
#   'lat': 31.9924964,
#   'lng': -102.1416877},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5380'),
#   'owner': 'MCLAUGHLIN SANDRA',
#   'address_1': '4702 LAURA DRMIDLAND, TX 79703',
#   'address_2': 'LAURA DR 4702',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4702 MIDLAND, TEXAS',
#   '2021_building_value': 167760.0,
#   '2021_land_value': 10900.0,
#   '2021_total_value': 178660.0,
#   'land_acre': 0.167,
#   'land_sqft': 7269.0,
#   'est_tax': 2666.17,
#   'total_sqft': 1173.0,
#   '$_per_building_sqft': 143.0,
#   '$_per_total_value_sqft': 152.3,
#   'lat': 31.9924474,
#   'lng': -102.1418552},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5381'),
#   'owner': 'BAKER RICKY H',
#   'address_1': 'PO BOX 4653MIDLAND, TX 79704-4653',
#   'address_2': 'LAURA DR 4704',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4704 MIDLAND, TEXAS',
#   '2021_building_value': 182730.0,
#   '2021_land_value': 10900.0,
#   '2021_total_value': 193630.0,
#   'land_acre': 0.167,
#   'land_sqft': 7269.0,
#   'est_tax': 3373.35,
#   'total_sqft': 1482.0,
#   '$_per_building_sqft': 123.3,
#   '$_per_total_value_sqft': 130.7,
#   'lat': 31.9923679,
#   'lng': -102.1421493},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5382'),
#   'owner': 'PETTY HOUSTON K III',
#   'address_1': '4706 LAURA DRMIDLAND, TX 79703',
#   'address_2': 'LAURA DR 4706',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4706 MIDLAND, TEXAS',
#   '2021_building_value': 159300.0,
#   '2021_land_value': 10910.0,
#   '2021_total_value': 170210.0,
#   'land_acre': 0.167,
#   'land_sqft': 7275.0,
#   'est_tax': 2527.97,
#   'total_sqft': 1306.0,
#   '$_per_building_sqft': 122.0,
#   '$_per_total_value_sqft': 130.3,
#   'lat': 31.9923672,
#   'lng': -102.1422711},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5383'),
#   'owner': 'VANZANDT TREVOR',
#   'address_1': '4708 LAURA DRMIDLAND, TX 79703',
#   'address_2': 'LAURA DR 4708',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4708 MIDLAND, TEXAS',
#   '2021_building_value': 170900.0,
#   '2021_land_value': 10900.0,
#   '2021_total_value': 181800.0,
#   'land_acre': 0.167,
#   'land_sqft': 7269.0,
#   'est_tax': 3167.23,
#   'total_sqft': 1395.0,
#   '$_per_building_sqft': 122.5,
#   '$_per_total_value_sqft': 130.3,
#   'lat': 31.9922951,
#   'lng': -102.1425251},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5384'),
#   'owner': 'GUERRERO ERIC',
#   'address_1': '2401 W SHANDONMIDLAND, TX 79705',
#   'address_2': 'LAURA DR 4710',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4710 MIDLAND, TEXAS',
#   '2021_building_value': 151400.0,
#   '2021_land_value': 12730.0,
#   '2021_total_value': 164130.0,
#   'land_acre': 0.195,
#   'land_sqft': 8488.0,
#   'est_tax': 2428.41,
#   'total_sqft': 1560.0,
#   '$_per_building_sqft': 97.1,
#   '$_per_total_value_sqft': 105.2,
#   'lat': 31.9922735,
#   'lng': -102.1427484},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5385'),
#   'owner': 'POWERS PHIL K',
#   'address_1': '4712 LAURA DRMIDLAND, TX 79703',
#   'address_2': 'LAURA DR 4712',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4712 MIDLAND, TEXAS',
#   '2021_building_value': 143950.0,
#   '2021_land_value': 12830.0,
#   '2021_total_value': 156780.0,
#   'land_acre': 0.196,
#   'land_sqft': 8552.0,
#   'est_tax': 2307.88,
#   'total_sqft': 1503.0,
#   '$_per_building_sqft': 95.8,
#   '$_per_total_value_sqft': 104.3,
#   'lat': 31.9921743,
#   'lng': -102.1429828},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5386'),
#   'owner': 'MC CORMACK ANDREW',
#   'address_1': '4714 LAURA DRMIDLAND, TX 79703 5314',
#   'address_2': 'LAURA DR 4714',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4714 MIDLAND, TEXAS',
#   '2021_building_value': 162620.0,
#   '2021_land_value': 10500.0,
#   '2021_total_value': 173120.0,
#   'land_acre': 0.161,
#   'land_sqft': 7002.0,
#   'est_tax': 3016.03,
#   'total_sqft': 1346.0,
#   '$_per_building_sqft': 120.8,
#   '$_per_total_value_sqft': 128.6,
#   'lat': 31.9921428,
#   'lng': -102.143195},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5387'),
#   'owner': 'BALDERAS JOSE C',
#   'address_1': '6202 CHICKASAWMIDLAND, TX 79705',
#   'address_2': 'LAURA DR 4716',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4716 MIDLAND, TEXAS',
#   '2021_building_value': 155710.0,
#   '2021_land_value': 10500.0,
#   '2021_total_value': 166210.0,
#   'land_acre': 0.161,
#   'land_sqft': 7002.0,
#   'est_tax': 2895.63,
#   'total_sqft': 1328.0,
#   '$_per_building_sqft': 117.3,
#   '$_per_total_value_sqft': 125.2,
#   'lat': 31.9920775,
#   'lng': -102.1434183},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5388'),
#   'owner': 'GUZMAN GILBERT',
#   'address_1': '4718 LAURA DRMIDLAND, TX 79703',
#   'address_2': 'LAURA DR 4718',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4718 MIDLAND, TEXAS',
#   '2021_building_value': 197967.0,
#   '2021_land_value': 10500.0,
#   '2021_total_value': 208467.0,
#   'land_acre': 0.161,
#   'land_sqft': 7002.0,
#   'est_tax': 2478.93,
#   'total_sqft': 1753.0,
#   '$_per_building_sqft': 112.9,
#   '$_per_total_value_sqft': 118.9,
#   'lat': 31.9920524,
#   'lng': -102.1436229},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5389'),
#   'owner': 'SMITH JIMMY D',
#   'address_1': '4722 LAURA DRMIDLAND, TX 79703-5314',
#   'address_2': 'LAURA DR 4722',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4722 MIDLAND, TEXAS',
#   '2021_building_value': 178920.0,
#   '2021_land_value': 10500.0,
#   '2021_total_value': 187140.0,
#   'land_acre': 0.161,
#   'land_sqft': 7002.0,
#   'est_tax': 1206.16,
#   'total_sqft': 1665.0,
#   '$_per_building_sqft': 107.5,
#   '$_per_total_value_sqft': 112.4,
#   'lat': 31.9919784,
#   'lng': -102.1440499},
#  {'_id': ObjectId('61e60f8e68822cfcae1f538a'),
#   'owner': 'GONZALES VIRGINIA',
#   'address_1': '3309 PERRY STMIDLAND, TX 79705',
#   'address_2': 'LAURA DR 4724',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4724 MIDLAND, TEXAS',
#   '2021_building_value': 161110.0,
#   '2021_land_value': 10500.0,
#   '2021_total_value': 171610.0,
#   'land_acre': 0.161,
#   'land_sqft': 7002.0,
#   'est_tax': 2989.72,
#   'total_sqft': 1581.0,
#   '$_per_building_sqft': 101.9,
#   '$_per_total_value_sqft': 108.5,
#   'lat': 31.9919092,
#   'lng': -102.1442774},
#  {'_id': ObjectId('61e60f8e68822cfcae1f538b'),
#   'owner': 'HURST MARI NELL',
#   'address_1': '4726 LAURA DRMIDLAND, TX 79703',
#   'address_2': 'LAURA DR 4726',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'LAURA DR   4726 MIDLAND, TEXAS',
#   '2021_building_value': 168490.0,
#   '2021_land_value': 10500.0,
#   '2021_total_value': 178990.0,
#   'land_acre': 0.161,
#   'land_sqft': 7002.0,
#   'est_tax': 1051.76,
#   'total_sqft': 1356.0,
#   '$_per_building_sqft': 124.3,
#   '$_per_total_value_sqft': 132.0,
#   'lat': 31.9918469,
#   'lng': -102.1444455},
#  {'_id': ObjectId('61e60f8e68822cfcae1f538c'),
#   'owner': 'RAMIREZ LAWRENCE DALE',
#   'address_1': '4731 W CUTHBERT AVMIDLAND, TX 79703',
#   'address_2': 'CUTHBERT AV 4731 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4731   W MIDLAND, TEXAS',
#   '2021_building_value': 180970.0,
#   '2021_land_value': 9980.0,
#   '2021_total_value': 190950.0,
#   'land_acre': 0.153,
#   'land_sqft': 6653.0,
#   'est_tax': 2867.19,
#   'total_sqft': 1742.0,
#   '$_per_building_sqft': 103.9,
#   '$_per_total_value_sqft': 109.6,
#   'lat': 31.9921451,
#   'lng': -102.1449814},
#  {'_id': ObjectId('61e60f8e68822cfcae1f538d'),
#   'owner': 'BUCHANAN JOE',
#   'address_1': '4729 W CUTHBERT AVEMIDLAND, TX 79703-5305',
#   'address_2': 'CUTHBERT AV 4729 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4729   W MIDLAND, TEXAS',
#   '2021_building_value': 167160.0,
#   '2021_land_value': 10540.0,
#   '2021_total_value': 177700.0,
#   'land_acre': 0.161,
#   'land_sqft': 7028.0,
#   'est_tax': 1125.62,
#   'total_sqft': 1362.0,
#   '$_per_building_sqft': 122.7,
#   '$_per_total_value_sqft': 130.5,
#   'lat': 31.9922061,
#   'lng': -102.1448028},
#  {'_id': ObjectId('61e60f8e68822cfcae1f538e'),
#   'owner': 'BUTLER JENNA',
#   'address_1': '4727 W CUTHBERT AVMIDLAND, TX 79703',
#   'address_2': 'CUTHBERT AV 4727 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4727   W MIDLAND, TEXAS',
#   '2021_building_value': 193000.0,
#   '2021_land_value': 10540.0,
#   '2021_total_value': 203540.0,
#   'land_acre': 0.161,
#   'land_sqft': 7028.0,
#   'est_tax': 3073.1,
#   'total_sqft': 1362.0,
#   '$_per_building_sqft': 141.7,
#   '$_per_total_value_sqft': 149.4,
#   'lat': 31.9922314,
#   'lng': -102.1446076},
#  {'_id': ObjectId('61e60f8e68822cfcae1f538f'),
#   'owner': 'LEWIS STEPHANIE J',
#   'address_1': '4725 W CUTHBERT AVEMIDLAND, TX 79703',
#   'address_2': 'CUTHBERT AV 4725 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4725   W MIDLAND, TEXAS',
#   '2021_building_value': 183000.0,
#   '2021_land_value': 10540.0,
#   '2021_total_value': 193350.0,
#   'land_acre': 0.161,
#   'land_sqft': 7028.0,
#   'est_tax': 2906.44,
#   'total_sqft': 1488.0,
#   '$_per_building_sqft': 123.0,
#   '$_per_total_value_sqft': 129.9,
#   'lat': 31.9922931,
#   'lng': -102.1443719},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5390'),
#   'owner': 'VILLAPANDO MARIA',
#   'address_1': '& JOSELITO MONTOYA4723 W CUTHBERT AVMIDLAND, TX 79703',
#   'address_2': 'CUTHBERT AV 4723 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4723   W MIDLAND, TEXAS',
#   '2021_building_value': 162610.0,
#   '2021_land_value': 10540.0,
#   '2021_total_value': 173150.0,
#   'land_acre': 0.161,
#   'land_sqft': 7028.0,
#   'est_tax': 2576.05,
#   'total_sqft': 1328.0,
#   '$_per_building_sqft': 122.4,
#   '$_per_total_value_sqft': 130.4,
#   'lat': 31.9923103,
#   'lng': -102.1441775},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5391'),
#   'owner': 'WINDHAM BREANN',
#   'address_1': '4721 WEST CUTHBERT AVMIDLAND, TX 79703',
#   'address_2': 'CUTHBERT AV 4721 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4721   W MIDLAND, TEXAS',
#   '2021_building_value': 168470.0,
#   '2021_land_value': 10540.0,
#   '2021_total_value': 179010.0,
#   'land_acre': 0.161,
#   'land_sqft': 7028.0,
#   'est_tax': 3118.64,
#   'total_sqft': 1391.0,
#   '$_per_building_sqft': 121.1,
#   '$_per_total_value_sqft': 128.7,
#   'lat': 31.9923757,
#   'lng': -102.1439542},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5392'),
#   'owner': 'QUADRIGA INVESTMENTS INC',
#   'address_1': '4108 N BIG SPRING STMIDLAND, TX 79705',
#   'address_2': 'CUTHBERT AV 4719 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4719   W MIDLAND, TEXAS',
#   '2021_building_value': 132020.0,
#   '2021_land_value': 10540.0,
#   '2021_total_value': 142560.0,
#   'land_acre': 0.161,
#   'land_sqft': 7028.0,
#   'est_tax': 2483.6,
#   'total_sqft': 1188.0,
#   '$_per_building_sqft': 111.1,
#   '$_per_total_value_sqft': 120.0,
#   'lat': 31.9924481,
#   'lng': -102.1437544},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5393'),
#   'owner': 'NEATHERLIN CAMERON D',
#   'address_1': '& JOE L COOK4717 W CUTHBERT AVMIDLAND, TX 79703',
#   'address_2': 'CUTHBERT AV 4717 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4717   W MIDLAND, TEXAS',
#   '2021_building_value': 175380.0,
#   '2021_land_value': 10540.0,
#   '2021_total_value': 185920.0,
#   'land_acre': 0.161,
#   'land_sqft': 7028.0,
#   'est_tax': 2784.91,
#   'total_sqft': 1328.0,
#   '$_per_building_sqft': 132.1,
#   '$_per_total_value_sqft': 140.0,
#   'lat': 31.9924725,
#   'lng': -102.1435691},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5394'),
#   'owner': 'GRAY CAULIE DAN',
#   'address_1': '4715 W CUTHBERT AVMIDLAND, TX 79703',
#   'address_2': 'CUTHBERT AV 4715 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4715   W MIDLAND, TEXAS',
#   '2021_building_value': 180870.0,
#   '2021_land_value': 10540.0,
#   '2021_total_value': 191410.0,
#   'land_acre': 0.161,
#   'land_sqft': 7028.0,
#   'est_tax': 2874.7,
#   'total_sqft': 1386.0,
#   '$_per_building_sqft': 130.5,
#   '$_per_total_value_sqft': 138.1,
#   'lat': 31.99252689999999,
#   'lng': -102.1434078},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5395'),
#   'owner': 'SVG INVESTMENTS LLC',
#   'address_1': 'PO BOX 4022MIDLAND, TX 79704',
#   'address_2': 'CUTHBERT AV 4713 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4713   W MIDLAND, TEXAS',
#   '2021_building_value': 204200.0,
#   '2021_land_value': 12880.0,
#   '2021_total_value': 217080.0,
#   'land_acre': 0.197,
#   'land_sqft': 8584.0,
#   'est_tax': 3781.87,
#   'total_sqft': 1791.0,
#   '$_per_building_sqft': 114.0,
#   '$_per_total_value_sqft': 121.2,
#   'lat': 31.99254609999999,
#   'lng': -102.1431729},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5396'),
#   'owner': 'WILLIAMS ROBERT',
#   'address_1': '4711 W CUTHBERT AVEMIDLAND, TX 79703',
#   'address_2': 'CUTHBERT AV 4711 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4711   W MIDLAND, TEXAS',
#   '2021_building_value': 154310.0,
#   '2021_land_value': 12780.0,
#   '2021_total_value': 167090.0,
#   'land_acre': 0.196,
#   'land_sqft': 8520.0,
#   'est_tax': 2910.97,
#   'total_sqft': 1308.0,
#   '$_per_building_sqft': 118.0,
#   '$_per_total_value_sqft': 127.7,
#   'lat': 31.9926415,
#   'lng': -102.1428051},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5397'),
#   'owner': 'ELLIS RANDOLPH',
#   'address_1': '201 E DENGAR AVEMIDLAND, TX 79705-5606',
#   'address_2': 'CUTHBERT AV 4709 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4709   W MIDLAND, TEXAS',
#   '2021_building_value': 134850.0,
#   '2021_land_value': 10940.0,
#   '2021_total_value': 145790.0,
#   'land_acre': 0.167,
#   'land_sqft': 7296.0,
#   'est_tax': 2539.89,
#   'total_sqft': 1503.0,
#   '$_per_building_sqft': 89.7,
#   '$_per_total_value_sqft': 97.0,
#   'lat': 31.9926759,
#   'lng': -102.1426591},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5398'),
#   'owner': 'ELKINS KENNETH EUGENE',
#   'address_1': '4707 W CUTHBERT AVMIDLAND, TX 79703',
#   'address_2': 'CUTHBERT AV 4707 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4707   W MIDLAND, TEXAS',
#   '2021_building_value': 207070.0,
#   '2021_land_value': 10940.0,
#   '2021_total_value': 218010.0,
#   'land_acre': 0.167,
#   'land_sqft': 7296.0,
#   'est_tax': 3309.77,
#   'total_sqft': 1308.0,
#   '$_per_building_sqft': 158.3,
#   '$_per_total_value_sqft': 166.7,
#   'lat': 31.99269829999999,
#   'lng': -102.1424554},
#  {'_id': ObjectId('61e60f8e68822cfcae1f5399'),
#   'owner': 'LEBARIO LIDIA',
#   'address_1': '4705 W CUTHBERT AVMIDLAND, TX 79707',
#   'address_2': 'CUTHBERT AV 4705 W',
#   'city': 'MIDLAND',
#   'state': 'TEXAS',
#   'full_address': 'CUTHBERT AV   4705   W MIDLAND, TEXAS',
#   '2021_building_value': 137280.0,
#   '2021_land_value': 10940.0,
#   '2021_total_value': 148220.0,
#   'land_acre': 0.167,
#   'land_sqft': 7296.0,
#   'est_tax': 1711.53,
#   'total_sqft': 1283.0,
#   '$_per_building_sqft': 107.0,
#   '$_per_total_value_sqft': 115.5,
#   'lat': 31.99278,
#   'lng': -102.1421853},
#  ...]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Alec\\Documents\\Programming_Resources\\Boot_Camp\\16_project03\\LOCAL\\IPYNB files'

# %%
data_no_dupes.to_csv('../clean_data/clean_home_no_dupes.csv',index=False)
data_no_dupes.to_json('../clean_data/clean_home_no_dupes.json')

# %%
data_no_dupes['$_per_building_sqft'].max()
# Out:
# 346.9
