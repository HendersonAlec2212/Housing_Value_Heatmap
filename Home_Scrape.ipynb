# %%
# Dependencies
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import urllib.request
import requests
import pandas as pd
import time
import re
import json
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import warnings

# %%
# DataFrame Set Up

header = ['Owner',
'Address 1',
'Address 2',
#'Street No.',
#'Street',
'City',
'State',
#'Zip',
'Full Address',
'2021 Building Value',
'2020 Building Value',
'2019 Building Value',
'2018 Building Value',
'2017 Building Value',
'2016 Building Value',
'2021 Land Value',
'2020 Land Value',
'2019 Land Value',
'2018 Land Value',
'2017 Land Value',
'2016 Land Value',
'2021 Total Value',
'2020 Total Value',
'2019 Total Value',
'2018 Total Value',
'2017 Total Value',
'2016 Total Value',
'Land (Acre)',
'Land (SQFT)',
'Est Tax',
'Improvement 1',
'Size 1',
'Improvement 2',
'Size 2',
'Improvement 3',
'Size 3',
'Improvement 4',
'Size 4',
'Improvement 5',
'Size 5',
'Improvement 6',
'Size 6',
'Improvement 7',
'Size 7',
'Improvement 8',
'Size 8',
'Improvement 9',
'Size 9',
'Improvement 10',
'Size 10'
#'Total Building SQFT',
#'Price/SQFT'   
]
rows=[]

# %%
for x in range(100,300):
    
    # URL Address
    bas_url = 'https://iswdataclient.azurewebsites.net/webProperty.aspx?dbkey=midlandcad&stype=id&sdata='
    tail_url = '&time=202201082009036&id=' 
    prop_id = 'R000040'+str(x)
    url = bas_url+prop_id+tail_url+prop_id
    html = requests.get(url)
    soup = BeautifulSoup(html.text,'lxml')

    row = []

    # HTML Tables 
    table = soup.find_all('tbody')
    table_address = table[1]
    table_legal = table[4]
    table_val = table[5]
    table_sqft = table[6]
    table_land = table[7]
    table_tax = table[9]

    # Data List

    acre_list = table_land.find_all('td')
    tax_row_list = table_tax.find_all('tr')
    tax_row_num = len(tax_row_list)-1
    last_tax_row = tax_row_list[tax_row_num]
    tax_col_list = last_tax_row.find_all('td')
    tax_col_num = len(tax_col_list)-1
 

    # Data Variables - Name & Address
    try:
        name = table_address.find('td', id ='webprop_name').text
        row.append(name)
    except:
        row.append(np.nan)   
    
    try:    
        address1 = table_address.find('td', id='webprop_mailaddress').text
        row.append(address1)
    except:
        row.append(np.nan)
        
    try:
        address2 = table_legal.find('td', id='webprop_situs').text
        address2 = address2[7:]
        row.append(address2)
    except:
        row.append(np.nan)
        
    #try:  
    #    address2_num = len(address2)-6
    #    street_no = address2[address2_num:]
    #    street_no = street_no.lstrip()
    #    row.append(street_no)
    #except:
    #    row.append(np.nan)

    #try:
    #    street = address2[:address2_num]
    #    street = street.rstrip()
    #    row.append(street)
    #except:
    #    row.append(np.nan)

    try:
        city = "MIDLAND"
        chars = address1.find("MIDLAND")

        if chars>0:
            row.append(city)
        else:
            row.append(np.nan)

        #city_num = len(address1)-10
        #city1 = address1[:city_num]
        #city_num2 = len(city1)-7
        #city = city1[city_num2:]
        #row.append(city)
    except:
        row.append(np.nan)
        
    state = 'TEXAS'
    row.append(state)
    
    #try:
    #    zip_code_num = len(address1)-6
    #    zip_code = address1[zip_code_num:]
    #    zip_code = zip_code.lstrip()
    #    row.append(zip_code)
    #except:
    #    row.append(np.nan)
        
    try:  
        full_address = address2+" "+city+", "+state
        row.append(full_address)
    except:
        row.append(np.nan)

    # Data Variables - Other
    try:
        imp0 = table_val.find('td', id='histimp0_yr').text
        row.append(imp0)
    except:
        row.append(np.nan)

    try:
        imp1 = table_val.find('td', id='histimp1_yr').text
        row.append(imp1)
    except:
        row.append(np.nan)
    
    try:
        imp2 = table_val.find('td', id='histimp2_yr').text
        row.append(imp2)
    except:
        row.append(np.nan)

    try:
        imp3 = table_val.find('td', id='histimp3_yr').text
        row.append(imp3)
    except:
        row.append(np.nan)
    
    try:
        imp4 = table_val.find('td', id='histimp4_yr').text
        row.append(imp4)
    except:
        row.append(np.nan)

    try:
        imp5 = table_val.find('td', id='histimp5_yr').text
        row.append(imp5)
    except:
        row.append(np.nan)
    
    try:
        land0 = table_val.find('td', id='histlnd0_yr').text
        row.append(land0)
    except:
        row.append(np.nan)
    
    try:
        land1 = table_val.find('td', id='histlnd1_yr').text
        row.append(land1)
    except:
        row.append(np.nan)
    
    try:
        land2 = table_val.find('td', id='histlnd2_yr').text
        row.append(land2)
    except:
        row.append(np.nan)
    
    try:
        land3 = table_val.find('td', id='histlnd3_yr').text
        row.append(land3)
    except:
        row.append(np.nan)
    
    try:
        land4 = table_val.find('td', id='histlnd4_yr').text
        row.append(land4)
    except:
        row.append(np.nan)

    try:
        land5 = table_val.find('td', id='histlnd5_yr').text
        row.append(land5)
    except:
        row.append(np.nan)

    try:    
        totval0 = table_val.find('td', id='histassd0_yr').text
        row.append(totval0)
    except:
        row.append(np.nan)
    
    try:
        totval1 = table_val.find('td', id='histassd1_yr').text
        row.append(totval1)
    except:
        row.append(np.nan)
    
    try:
        totval2 = table_val.find('td', id='histassd2_yr').text
        row.append(totval2)
    except:
        row.append(np.nan)
    
    try:
        totval3 = table_val.find('td', id='histassd3_yr').text
        row.append(totval3)
    except:
        row.append(np.nan)

    try:
        totval4 = table_val.find('td', id='histassd4_yr').text
        row.append(totval4)
    except:
        row.append(np.nan)
    
    try:
        totval5 = table_val.find('td', id='histassd5_yr').text
        row.append(totval5)
    except:
        row.append(np.nan)
    
    try:
        land_acre = acre_list[1].text
        row.append(land_acre)
    except:
        row.append(np.nan)

    try:
        land_sqft = acre_list[2].text
        row.append(land_sqft)
    except:
        row.append(np.nan)
    
    try:
        est_tax_val = tax_col_list[tax_col_num].text
        row.append(est_tax_val)
    except:
        row.append(np.nan)
    


# For Loop Land Details
    #try:
    #    sqft_row_list = table_sqft.find_all('tr')
    #    sqft_row_num = len(sqft_row_list)

    for x in range(10):
        try:
            sqft_row_list = table_sqft.find_all('tr')
            select_row = sqft_row_list[x]
            code = select_row.find_all('td')[1].text
            desc = select_row.find_all('td')[2].text
            year = select_row.find_all('td')[3].text
            sqft = select_row.find_all('td')[4].text
            row.append(code)
            #row.append(desc)
            #row.append(year)
            row.append(sqft)
        except:
            row.append(np.nan)
            #row.append(np.nan)
            #row.append(np.nan)
            row.append(np.nan)

    rows.append(row)
home_data = pd.DataFrame(data=rows,columns=header)

# %%
home_data.head(50)
# Out:
#                                 Owner  \
# 0                     PACELLI MICHAEL
# 1                     ADAMS KARLEEN B
# 2                       ELLIS EDWIN L
# 3                       MORALES JERRY
# 4                 LAWRENCE MARGARET E
# 5                     MORALES SOCORRO
# 6                    HIGGINS UNA FAYE
# 7                       EVANS HOLLY D
# 8                         BIGLEY JOHN
# 9                       HARRIS GARY F
# 10                      GOUDEAU ANITA
# 11                   RIGGAN TIMOTHY S
# 12                   MOONEY MICHAEL G
# 13                  KNITTLE RICHARD J
# 14               CARNETT JOHN RANDALL
# 15                       CONLEY RALPH
# 16                   MCFARLAND MARTHA
# 17                    ALDERMAN CURTIS
# 18       QUAIL POINT HOMEOWNERS ASSOC
# 19
# 20
# 21                     EUBANK HOLLY A
# 22                       SHICK GERALD
# 23                   VILLARREAL SAMMY
# 24                 WHITE ARNOLD SCOTT
# 25            GRAY II EVERETT WILLARD
# 26                   ROBERTS STEVEN D
# 27                        WARE LEZLYE
# 28        BECKETT LANE PROPERTIES LLC
# 29                      GARAY SCOTT L
# 30  SEYAH REAL ESTATE INVESTMENTS LLC
# 31
# 32                 RACQUET CLUB SOUTH
# 33                 RACQUET CLUB SOUTH
# 34                 RACQUET CLUB SOUTH
# 35                 RACQUET CLUB SOUTH
# 36                 RACQUET CLUB SOUTH
# 37                 RACQUET CLUB SOUTH
# 38                 RACQUET CLUB SOUTH
# 39                 RACQUET CLUB SOUTH
# 40                    HOLT HELEN JOAN
# 41                    DOUGLAS TERRY R
# 42               HICKEY WILLIAM MORAN
# 43                       KING SCOTT W
# 44          VAN MABEE REVOCABLE TRUST
# 45                  GEISELMAN ALLEN R
# 46                       KING JAMES B
# 47                  KEMP DEBBIE CONLY
# 48             COLLINS DIANA LORENZEN
# 49                       HORTON JAY B
#
#                                             Address 1               Address 2  \
# 0                   2514 QUAIL POINTMIDLAND, TX 79705      QUAIL POINT   2514
# 1                   2512 QUAIL POINTMIDLAND, TX 79705      QUAIL POINT   2512
# 2                   2510 QUAIL POINTMIDLAND, TX 79705      QUAIL POINT   2510
# 3                   2508 QUAIL POINTMIDLAND, TX 79705      QUAIL POINT   2508
# 4                   2506 QUAIL POINTMIDLAND, TX 79705      QUAIL POINT   2506
# 5                   2504 QUAIL POINTMIDLAND, TX 79705      QUAIL POINT   2504
# 6                 2502 QUAIL PTMIDLAND, TX 79705-6365      QUAIL POINT   2502
# 7                      2500 QUAIL PTMIDLAND, TX 79705      QUAIL POINT   2500
# 8                   2519 QUAIL POINTMIDLAND, TX 79705      QUAIL POINT   2519
# 9   & JOETTA K HARRIS2517 QUAIL POINTMIDLAND, TX 7...      QUAIL POINT   2517
# 10                  2515 QUAIL POINTMIDLAND, TX 79705      QUAIL POINT   2515
# 11                 217 BLACKBERRY CRMIDLAND, TX 79707      QUAIL POINT   2513
# 12           220 PARADISE CIRTOWNVILLE, SC 29689 3429      QUAIL POINT   2511
# 32  MIDLAND  TEXAS     RACQUET CLUB DR   0 MIDLAND, TEXAS                  $0
# 33  MIDLAND  TEXAS     RACQUET CLUB DR   0 MIDLAND, TEXAS                  $0
# 34  MIDLAND  TEXAS  RACQUET CLUB DR   2810 MIDLAND, TEXAS              $2,740
# 35  MIDLAND  TEXAS     RACQUET CLUB DR   0 MIDLAND, TEXAS                  $0
# 36  MIDLAND  TEXAS     RACQUET CLUB DR   0 MIDLAND, TEXAS                  $0
# 37  MIDLAND  TEXAS     RACQUET CLUB DR   0 MIDLAND, TEXAS                  $0
# 38  MIDLAND  TEXAS     RACQUET CLUB DR   0 MIDLAND, TEXAS                  $0
# 39  MIDLAND  TEXAS  RACQUET CLUB DR   2811 MIDLAND, TEXAS                $440
# 40  MIDLAND  TEXAS  RACQUET CLUB DR   2808 MIDLAND, TEXAS            $502,960
# 41  MIDLAND  TEXAS  RACQUET CLUB DR   2804 MIDLAND, TEXAS            $412,410
# 42  MIDLAND  TEXAS  RACQUET CLUB DR   2800 MIDLAND, TEXAS            $561,300
# 43  MIDLAND  TEXAS  RACQUET CLUB DR   2706 MIDLAND, TEXAS            $444,220
# 44  MIDLAND  TEXAS  RACQUET CLUB DR   2702 MIDLAND, TEXAS            $483,770
# 45  MIDLAND  TEXAS  RACQUET CLUB DR   2700 MIDLAND, TEXAS            $518,110
# 46  MIDLAND  TEXAS  RACQUET CLUB DR   2701 MIDLAND, TEXAS            $921,610
# 47  MIDLAND  TEXAS  RACQUET CLUB DR   2705 MIDLAND, TEXAS            $418,660
# 48  MIDLAND  TEXAS  RACQUET CLUB DR   2707 MIDLAND, TEXAS            $664,030
# 49  MIDLAND  TEXAS  RACQUET CLUB DR   2711 MIDLAND, TEXAS            $817,390
#
#    2020 Building Value 2019 Building Value 2018 Building Value  ...  \
# 0             $359,470            $359,470            $296,760  ...
# 1             $292,150            $292,150            $244,750  ...
# 2             $240,130            $240,130            $208,280  ...
# 3             $416,910            $416,910            $347,560  ...
# 4             $281,510            $281,510            $236,000  ...
# 5             $304,840            $304,840            $255,030  ...
# 6             $298,270            $298,270            $249,950  ...
# 7             $301,200            $301,200            $252,110  ...
# 8             $223,540            $223,540            $196,900  ...
# 9             $235,200            $235,200            $206,890  ...
# 10            $235,040            $221,662            $206,960  ...
# 11            $193,440            $193,440            $193,440  ...
# 12            $223,540            $223,540            $196,900  ...
# 13            $226,280            $226,280            $196,280  ...
# 14            $240,260            $240,260            $208,700  ...
# 15            $240,260            $240,260            $208,700  ...
# 16            $240,260            $240,260            $208,700  ...
# 17            $215,660            $215,660            $187,330  ...
# 18                  $0                  $0                  $0  ...
# 19                  $0                  $0                  $0  ...
# 20                  $0                  $0                  $0  ...
# 21            $259,180            $259,180            $233,340  ...
# 22            $252,650            $252,650            $227,620  ...
# 23            $309,720            $309,720            $277,940  ...
# 24            $127,850            $127,850            $115,170  ...
# 25            $362,440            $362,440            $332,790  ...
# 26            $357,820            $357,820            $328,590  ...
# 27            $334,200            $334,200            $300,170  ...
